# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/kyle/anaconda3/lib/python3.11/site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /Users/kyle/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/kyle/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/kyle/anaconda3/lib/python3.11/site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /Users/kyle/anaconda3/lib/python3.11/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /Users/kyle/anaconda3/lib/python3.11/site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kyle/anaconda3/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kyle/anaconda3/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kyle/anaconda3/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in /Users/kyle/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd

# Load the dataset
file_path = 'trades(final).csv'
data = pd.read_csv(file_path)

data['Open_Last_Return'] = data['Open'] - data['Last']

# List of features to test for stationarity
features_to_test = ['SMA5_At_Entry', 'SMA10_At_Entry', 'EMA5_At_Entry', 'EMA15_At_Entry', 'RSI5_At_Entry', 'RSI10_At_Entry',
                     'ATR5_At_Entry', 'ATR15_At_Entry', 'Stoch7_K_At_Entry', 'Stoch21_K_At_Entry',
                     'BB10_High_At_Entry', 'BB10_Low_At_Entry', 'BB10_MAvg_At_Entry',
                     'BB15_High_At_Entry', 'BB15_Low_At_Entry', 'BB15_MAvg_At_Entry',
                     'High', 'Low', 'MACD_At_Entry', 'Day_Of_Week_At_Entry',
                     'ROC14_At_Entry' , 'ROC15_At_Entry', 'Open_Last_Return'
                     ]
# Function to perform ADF test and print results
def adf_test(series, feature_name):
    result = adfuller(series.dropna(), autolag='AIC')
    adf_statistic = result[0]
    p_value = result[1]
    critical_values = result[4]
    
    print(f'ADF Statistic for {feature_name}: {adf_statistic}')
    print(f'p-value for {feature_name}: {p_value}')
    print(f'Critical Values for {feature_name}: {critical_values}')
    
    if p_value < 0.05:
        print(f"Reject the null hypothesis: The {feature_name} data is likely stationary.\n")
    else:
        print(f"Fail to reject the null hypothesis: The {feature_name} data is likely non-stationary.\n")

# Apply the ADF test on each feature
for feature in features_to_test:
    adf_test(data[feature], feature)
# Out:
# ADF Statistic for SMA5_At_Entry: -0.47994219614162215
# p-value for SMA5_At_Entry: 0.8958715667697705
# Critical Values for SMA5_At_Entry: {'1%': -3.4310561549262273, '5%': -2.8618520757372328, '10%': -2.566936112841357}
# Fail to reject the null hypothesis: The SMA5_At_Entry data is likely non-stationary.
#
# ADF Statistic for SMA10_At_Entry: -0.41100825453851636
# p-value for SMA10_At_Entry: 0.9082445047166416
# Critical Values for SMA10_At_Entry: {'1%': -3.431056231189538, '5%': -2.861852109436778, '10%': -2.56693613077977}
# Fail to reject the null hypothesis: The SMA10_At_Entry data is likely non-stationary.
#
# ADF Statistic for EMA5_At_Entry: -0.4815117315278632
# p-value for EMA5_At_Entry: 0.8955741422310382
# Critical Values for EMA5_At_Entry: {'1%': -3.4310561549262273, '5%': -2.8618520757372328, '10%': -2.566936112841357}
# Fail to reject the null hypothesis: The EMA5_At_Entry data is likely non-stationary.
#
# ADF Statistic for EMA15_At_Entry: -0.39960124304366773
# p-value for EMA15_At_Entry: 0.9101653342111895
# Critical Values for EMA15_At_Entry: {'1%': -3.431056383765587, '5%': -2.861852176857708, '10%': -2.5669361666682216}
# Fail to reject the null hypothesis: The EMA15_At_Entry data is likely non-stationary.
#
# ADF Statistic for RSI5_At_Entry: -30.75293392240136
# p-value for RSI5_At_Entry: 0.0
# Critical Values for RSI5_At_Entry: {'1%': -3.4310554692968998, '5%': -2.8618517727684862, '10%': -2.5669359515697945}
# Reject the null hypothesis: The RSI5_At_Entry data is likely stationary.
#
# ADF Statistic for RSI10_At_Entry: -21.946949448494674
# p-value for RSI10_At_Entry: 0.0
# Critical Values for RSI10_At_Entry: {'1%': -3.431055545412181, '5%': -2.8618518064026275, '10%': -2.5669359694733913}
# Reject the null hypothesis: The RSI10_At_Entry data is likely stationary.
#
# ADF Statistic for ATR5_At_Entry: -4.734372697500181
# p-value for ATR5_At_Entry: 7.249249909701726e-05
# Critical Values for ATR5_At_Entry: {'1%': -3.431057453646652, '5%': -2.8618526496210386, '10%': -2.5669364183221988}
# Reject the null hypothesis: The ATR5_At_Entry data is likely stationary.
#
# ADF Statistic for ATR15_At_Entry: -4.346058853981286
# p-value for ATR15_At_Entry: 0.0003693381263493972
# Critical Values for ATR15_At_Entry: {'1%': -3.431056078679386, '5%': -2.8618520420449642, '10%': -2.566936094906817}
# Reject the null hypothesis: The ATR15_At_Entry data is likely stationary.
#
# ADF Statistic for Stoch7_K_At_Entry: -28.951214032562458
# p-value for Stoch7_K_At_Entry: 0.0
# Critical Values for Stoch7_K_At_Entry: {'1%': -3.4310560024490084, '5%': -2.8618520083599694, '10%': -2.5669360769761496}
# Reject the null hypothesis: The Stoch7_K_At_Entry data is likely stationary.
#
# ADF Statistic for Stoch21_K_At_Entry: -23.49842022654898
# p-value for Stoch21_K_At_Entry: 0.0
# Critical Values for Stoch21_K_At_Entry: {'1%': -3.4310563074693228, '5%': -2.8618521431436026, '10%': -2.566936148722058}
# Reject the null hypothesis: The Stoch21_K_At_Entry data is likely stationary.
#
# ADF Statistic for BB10_High_At_Entry: -0.5598411605797566
# p-value for BB10_High_At_Entry: 0.879800570458394
# Critical Values for BB10_High_At_Entry: {'1%': -3.4310558500376227, '5%': -2.861851941011793, '10%': -2.5669360411264264}
# Fail to reject the null hypothesis: The BB10_High_At_Entry data is likely non-stationary.
#
# ADF Statistic for BB10_Low_At_Entry: -0.36253674684441073
# p-value for BB10_Low_At_Entry: 0.9161684004730184
# Critical Values for BB10_Low_At_Entry: {'1%': -3.4310576833286595, '5%': -2.8618527511138216, '10%': -2.566936472347253}
# Fail to reject the null hypothesis: The BB10_Low_At_Entry data is likely non-stationary.
#
# ADF Statistic for BB10_MAvg_At_Entry: -0.41100825453851636
# p-value for BB10_MAvg_At_Entry: 0.9082445047166416
# Critical Values for BB10_MAvg_At_Entry: {'1%': -3.431056231189538, '5%': -2.861852109436778, '10%': -2.56693613077977}
# Fail to reject the null hypothesis: The BB10_MAvg_At_Entry data is likely non-stationary.
#
# ADF Statistic for BB15_High_At_Entry: -0.5199669482375504
# p-value for BB15_High_At_Entry: 0.8880608329212524
# Critical Values for BB15_High_At_Entry: {'1%': -3.4310572241136845, '5%': -2.861852548194106, '10%': -2.566936364332199}
# Fail to reject the null hypothesis: The BB15_High_At_Entry data is likely non-stationary.
#
# ADF Statistic for BB15_Low_At_Entry: -0.27651031673226634
# p-value for BB15_Low_At_Entry: 0.9287659170921584
# Critical Values for BB15_Low_At_Entry: {'1%': -3.4310573771191097, '5%': -2.8618526158047475, '10%': -2.566936400321639}
# Fail to reject the null hypothesis: The BB15_Low_At_Entry data is likely non-stationary.
#
# ADF Statistic for BB15_MAvg_At_Entry: -0.35926931093686754
# p-value for BB15_MAvg_At_Entry: 0.9166804551532732
# Critical Values for BB15_MAvg_At_Entry: {'1%': -3.4310569183013184, '5%': -2.8618524130605194, '10%': -2.566936292400002}
# Fail to reject the null hypothesis: The BB15_MAvg_At_Entry data is likely non-stationary.
#
# ADF Statistic for High: -0.5258920336109352
# p-value for High: 0.8868640391259556
# Critical Values for High: {'1%': -3.4310582198337616, '5%': -2.861852988186763, '10%': -2.566936598542225}
# Fail to reject the null hypothesis: The High data is likely non-stationary.
#
# ADF Statistic for Low: -0.3659502052679928
# p-value for Low: 0.9156305313713331
# Critical Values for Low: {'1%': -3.431056231189538, '5%': -2.861852109436778, '10%': -2.56693613077977}
# Fail to reject the null hypothesis: The Low data is likely non-stationary.
#
# ADF Statistic for MACD_At_Entry: -13.114139180428351
# p-value for MACD_At_Entry: 1.6120970770502924e-24
# Critical Values for MACD_At_Entry: {'1%': -3.431057606751421, '5%': -2.8618527172755734, '10%': -2.5669364543350044}
# Reject the null hypothesis: The MACD_At_Entry data is likely stationary.
#
# ADF Statistic for Day_Of_Week_At_Entry: -32.787123908891324
# p-value for Day_Of_Week_At_Entry: 0.0
# Critical Values for Day_Of_Week_At_Entry: {'1%': -3.431056078679386, '5%': -2.8618520420449642, '10%': -2.566936094906817}
# Reject the null hypothesis: The Day_Of_Week_At_Entry data is likely stationary.
#
# ADF Statistic for ROC14_At_Entry: -13.880998772591427
# p-value for ROC14_At_Entry: 6.21150233209488e-26
# Critical Values for ROC14_At_Entry: {'1%': -3.4310583732703774, '5%': -2.8618530559879183, '10%': -2.5669366346330804}
# Reject the null hypothesis: The ROC14_At_Entry data is likely stationary.
#
# ADF Statistic for ROC15_At_Entry: -14.025561634806484
# p-value for ROC15_At_Entry: 3.508530735698824e-26
# Critical Values for ROC15_At_Entry: {'1%': -3.431058603550001, '5%': -2.861853157744747, '10%': -2.566936688798692}
# Reject the null hypothesis: The ROC15_At_Entry data is likely stationary.
#
# ADF Statistic for Open_Last_Return: -20.68184290878764
# p-value for Open_Last_Return: 0.0
# Critical Values for Open_Last_Return: {'1%': -3.431056994729613, '5%': -2.86185244683296, '10%': -2.566936310377219}
# Reject the null hypothesis: The Open_Last_Return data is likely stationary.
