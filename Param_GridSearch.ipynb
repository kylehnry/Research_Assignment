# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from itertools import product

# Load the datasets
train_data = pd.read_csv('train_data.csv')
val_data = pd.read_csv('val_data.csv')
test_data = pd.read_csv('test_data.csv')

# Ensure the data is sorted by the 'Entry_Date' column
train_data['Entry_Date'] = pd.to_datetime(train_data['Entry_Date'])
val_data['Entry_Date'] = pd.to_datetime(val_data['Entry_Date'])
test_data['Entry_Date'] = pd.to_datetime(test_data['Entry_Date'])

train_data = train_data.sort_values(by='Entry_Date')
val_data = val_data.sort_values(by='Entry_Date')
test_data = test_data.sort_values(by='Entry_Date')

# List of feature columns to include
feature_columns = [
    'SMA5_At_Entry', 'SMA7_At_Entry', 'EMA5_At_Entry', 'EMA15_At_Entry',
    'RSI5_At_Entry', 'RSI10_At_Entry', 'ATR5_At_Entry', 'ATR15_At_Entry',
    'Stoch5_K_At_Entry', 'Stoch7_K_At_Entry', 'BB5_High_At_Entry', 'BB5_Low_At_Entry',
    'BB5_MAvg_At_Entry', 'BB10_High_At_Entry', 'BB10_Low_At_Entry', 'BB10_MAvg_At_Entry',
    'Open', 'High', 'Low', 'Last', 'MACD_At_Entry', 'Day_Of_Week_At_Entry', 'ROC14_At_Entry'
]

# Separating features and target variable for training data
X_train = train_data[feature_columns]
y_train = train_data['Target']

# Separating features and target variable for validation data
X_val = val_data[feature_columns]
y_val = val_data['Target']

# Separating features and target variable for test data
X_test = test_data[feature_columns]
y_test = test_data['Target']

# Define the parameter grid for the RandomForestClassifier
param_grid = {
    'n_estimators': [5, 10, 50, 100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10, 25],
    'min_samples_leaf': [1, 2, 4, 5]
}

# Initialize a DataFrame to store the results
results = pd.DataFrame(columns=[
    'n_estimators', 'max_depth', 'min_samples_split', 'min_samples_leaf',
    'roc_auc_val', 'roc_auc_test', 'roc_auc_diff'
])

# Iterate through all combinations of parameters
for n_estimators, max_depth, min_samples_split, min_samples_leaf in product(
    param_grid['n_estimators'],
    param_grid['max_depth'],
    param_grid['min_samples_split'],
    param_grid['min_samples_leaf']
):
    # Initialize the Random Forest Classifier with specific parameters
    rf_clf = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42
    )
    
    # Fit the model to the training data
    rf_clf.fit(X_train, y_train)
    
    # Predict on the validation set
    y_val_pred = rf_clf.predict_proba(X_val)[:, 1]
    roc_auc_val = roc_auc_score(y_val, y_val_pred)
    
    # Predict on the test set
    y_test_pred = rf_clf.predict_proba(X_test)[:, 1]
    roc_auc_test = roc_auc_score(y_test, y_test_pred)
    
    # Calculate the difference between validation and test ROC AUC
    roc_auc_diff = abs(roc_auc_val - roc_auc_test)
    
    # Print the results for this combination
    print(f"n_estimators: {n_estimators}, max_depth: {max_depth}, min_samples_split: {min_samples_split}, min_samples_leaf: {min_samples_leaf}")
    print(f"Validation ROC AUC: {roc_auc_val}, Test ROC AUC: {roc_auc_test}, Difference: {roc_auc_diff}\n")
    
    # Create a DataFrame with the current results
    current_result = pd.DataFrame([{
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'min_samples_split': min_samples_split,
        'min_samples_leaf': min_samples_leaf,
        'roc_auc_val': roc_auc_val,
        'roc_auc_test': roc_auc_test,
        'roc_auc_diff': roc_auc_diff
    }])
    
    # Concatenate the current result to the results DataFrame
    results = pd.concat([results, current_result], ignore_index=True)

# Find the best combination of parameters based on the smallest difference in ROC AUC scores
best_params = results.loc[results['roc_auc_diff'].idxmin()]
print("\nBest parameters based on smallest ROC AUC difference:")
print(best_params)

# Save the results to a CSV file
results.to_csv('grid_search_results.csv', index=False)
# Out:
# n_estimators: 5, max_depth: None, min_samples_split: 2, min_samples_leaf: 1
# Validation ROC AUC: 0.5025199731202867, Test ROC AUC: 0.5128452794354501, Difference: 0.010325306315163374
#
# n_estimators: 5, max_depth: None, min_samples_split: 2, min_samples_leaf: 2
# Validation ROC AUC: 0.5114238781452998, Test ROC AUC: 0.5246478545427462, Difference: 0.013223976397446435
#
# n_estimators: 5, max_depth: None, min_samples_split: 2, min_samples_leaf: 4
# Validation ROC AUC: 0.49659103636227875, Test ROC AUC: 0.5022878981128913, Difference: 0.00569686175061257
#
# n_estimators: 5, max_depth: None, min_samples_split: 2, min_samples_leaf: 5
# Validation ROC AUC: 0.5254213955051146, Test ROC AUC: 0.49508439388156, Difference: 0.03033700162355457
#
# n_estimators: 5, max_depth: None, min_samples_split: 5, min_samples_leaf: 1
# Validation ROC AUC: 0.5150615060106026, Test ROC AUC: 0.49572211929654697, Difference: 0.019339386714055662
#
# n_estimators: 5, max_depth: None, min_samples_split: 5, min_samples_leaf: 2
# Validation ROC AUC: 0.4961290412902263, Test ROC AUC: 0.5014290635211753, Difference: 0.005300022230949053
#
# n_estimators: 5, max_depth: None, min_samples_split: 5, min_samples_leaf: 4
# Validation ROC AUC: 0.49659103636227875, Test ROC AUC: 0.5022878981128913, Difference: 0.00569686175061257
#
# n_estimators: 5, max_depth: None, min_samples_split: 5, min_samples_leaf: 5
# Validation ROC AUC: 0.5254213955051146, Test ROC AUC: 0.49508439388156, Difference: 0.03033700162355457
#
# n_estimators: 5, max_depth: None, min_samples_split: 10, min_samples_leaf: 1
# Validation ROC AUC: 0.5372956021802434, Test ROC AUC: 0.5168229171515553, Difference: 0.020472685028688153
#
# n_estimators: 5, max_depth: None, min_samples_split: 10, min_samples_leaf: 2
# Validation ROC AUC: 0.5051356118868066, Test ROC AUC: 0.4961270982097139, Difference: 0.009008513677092655
#
# n_estimators: 5, max_depth: None, min_samples_split: 10, min_samples_leaf: 4
# Validation ROC AUC: 0.5056652729037557, Test ROC AUC: 0.5018573170845242, Difference: 0.0038079558192315455
#
# n_estimators: 5, max_depth: None, min_samples_split: 10, min_samples_leaf: 5
# Validation ROC AUC: 0.5254213955051146, Test ROC AUC: 0.49508439388156, Difference: 0.03033700162355457
#
# n_estimators: 5, max_depth: None, min_samples_split: 25, min_samples_leaf: 1
# Validation ROC AUC: 0.4930607406854327, Test ROC AUC: 0.5095146769944048, Difference: 0.016453936308972072
#
# n_estimators: 5, max_depth: None, min_samples_split: 25, min_samples_leaf: 2
# Validation ROC AUC: 0.5114052116777421, Test ROC AUC: 0.5340577956113319, Difference: 0.02265258393358982
#
# n_estimators: 5, max_depth: None, min_samples_split: 25, min_samples_leaf: 4
# Validation ROC AUC: 0.5064562644665124, Test ROC AUC: 0.4934109465334736, Difference: 0.013045317933038758
#
# n_estimators: 5, max_depth: None, min_samples_split: 25, min_samples_leaf: 5
# Validation ROC AUC: 0.5183841372358695, Test ROC AUC: 0.5208168471227876, Difference: 0.0024327098869181274
#
# n_estimators: 5, max_depth: 10, min_samples_split: 2, min_samples_leaf: 1
# Validation ROC AUC: 0.5218001007989248, Test ROC AUC: 0.5068567119436195, Difference: 0.014943388855305328
#
# n_estimators: 5, max_depth: 10, min_samples_split: 2, min_samples_leaf: 2
# Validation ROC AUC: 0.485755151945046, Test ROC AUC: 0.4804865332874047, Difference: 0.0052686186576412775
#
# n_estimators: 5, max_depth: 10, min_samples_split: 2, min_samples_leaf: 4
# Validation ROC AUC: 0.4926757447920556, Test ROC AUC: 0.5115628462104214, Difference: 0.018887101418365748
#
# n_estimators: 5, max_depth: 10, min_samples_split: 2, min_samples_leaf: 5
# Validation ROC AUC: 0.5109688829985815, Test ROC AUC: 0.4781195013638946, Difference: 0.03284938163468687
#
# n_estimators: 5, max_depth: 10, min_samples_split: 5, min_samples_leaf: 1
# Validation ROC AUC: 0.49894301127454643, Test ROC AUC: 0.4963877742917524, Difference: 0.002555236982794029
#
# n_estimators: 5, max_depth: 10, min_samples_split: 5, min_samples_leaf: 2
# Validation ROC AUC: 0.5038336257746584, Test ROC AUC: 0.47396730377142426, Difference: 0.029866322003234136
#
# n_estimators: 5, max_depth: 10, min_samples_split: 5, min_samples_leaf: 4
# Validation ROC AUC: 0.4926757447920556, Test ROC AUC: 0.5115628462104214, Difference: 0.018887101418365748
#
# n_estimators: 5, max_depth: 10, min_samples_split: 5, min_samples_leaf: 5
# Validation ROC AUC: 0.5109688829985815, Test ROC AUC: 0.4781195013638946, Difference: 0.03284938163468687
#
# n_estimators: 5, max_depth: 10, min_samples_split: 10, min_samples_leaf: 1
# Validation ROC AUC: 0.5168908198312552, Test ROC AUC: 0.5284718795676501, Difference: 0.011581059736394894
#
# n_estimators: 5, max_depth: 10, min_samples_split: 10, min_samples_leaf: 2
# Validation ROC AUC: 0.5421442171283506, Test ROC AUC: 0.50166879241805, Difference: 0.040475424710300634
#
# n_estimators: 5, max_depth: 10, min_samples_split: 10, min_samples_leaf: 4
# Validation ROC AUC: 0.5124972000298664, Test ROC AUC: 0.48814622066230345, Difference: 0.024350979367562975
#
# n_estimators: 5, max_depth: 10, min_samples_split: 10, min_samples_leaf: 5
# Validation ROC AUC: 0.5109688829985815, Test ROC AUC: 0.4781195013638946, Difference: 0.03284938163468687
#
# n_estimators: 5, max_depth: 10, min_samples_split: 25, min_samples_leaf: 1
# Validation ROC AUC: 0.5055649406406332, Test ROC AUC: 0.48955899192835134, Difference: 0.016005948712281837
#
# n_estimators: 5, max_depth: 10, min_samples_split: 25, min_samples_leaf: 2
# Validation ROC AUC: 0.5161768274471739, Test ROC AUC: 0.488476720694888, Difference: 0.027700106752285847
#
# n_estimators: 5, max_depth: 10, min_samples_split: 25, min_samples_leaf: 4
# Validation ROC AUC: 0.5131901926379452, Test ROC AUC: 0.4948563023097763, Difference: 0.0183338903281689
#
# n_estimators: 5, max_depth: 10, min_samples_split: 25, min_samples_leaf: 5
# Validation ROC AUC: 0.5046876166654223, Test ROC AUC: 0.4975957286361986, Difference: 0.00709188802922367
#
# n_estimators: 5, max_depth: 20, min_samples_split: 2, min_samples_leaf: 1
# Validation ROC AUC: 0.5152645038452923, Test ROC AUC: 0.49182594285607883, Difference: 0.023438560989213486
#
# n_estimators: 5, max_depth: 20, min_samples_split: 2, min_samples_leaf: 2
# Validation ROC AUC: 0.49948900545060854, Test ROC AUC: 0.5266960237587629, Difference: 0.027207018308154363
#
# n_estimators: 5, max_depth: 20, min_samples_split: 2, min_samples_leaf: 4
# Validation ROC AUC: 0.4975756925259464, Test ROC AUC: 0.4900826715574465, Difference: 0.007493020968499908
#
# n_estimators: 5, max_depth: 20, min_samples_split: 2, min_samples_leaf: 5
# Validation ROC AUC: 0.5049139475845591, Test ROC AUC: 0.4859537486151583, Difference: 0.01896019896940082
#
# n_estimators: 5, max_depth: 20, min_samples_split: 5, min_samples_leaf: 1
# Validation ROC AUC: 0.504617617412081, Test ROC AUC: 0.502783648161768, Difference: 0.0018339692503129834
#
# n_estimators: 5, max_depth: 20, min_samples_split: 5, min_samples_leaf: 2
# Validation ROC AUC: 0.508325244530725, Test ROC AUC: 0.4943838269110815, Difference: 0.013941417619643515
#
# n_estimators: 5, max_depth: 20, min_samples_split: 5, min_samples_leaf: 4
# Validation ROC AUC: 0.4975756925259464, Test ROC AUC: 0.4900826715574465, Difference: 0.007493020968499908
#
# n_estimators: 5, max_depth: 20, min_samples_split: 5, min_samples_leaf: 5
# Validation ROC AUC: 0.5049139475845591, Test ROC AUC: 0.4859537486151583, Difference: 0.01896019896940082
#
# n_estimators: 5, max_depth: 20, min_samples_split: 10, min_samples_leaf: 1
# Validation ROC AUC: 0.502316975285597, Test ROC AUC: 0.4974584082001247, Difference: 0.004858567085472332
#
# n_estimators: 5, max_depth: 20, min_samples_split: 10, min_samples_leaf: 2
# Validation ROC AUC: 0.49268741133427907, Test ROC AUC: 0.4854370513811177, Difference: 0.007250359953161367
#
# n_estimators: 5, max_depth: 20, min_samples_split: 10, min_samples_leaf: 4
# Validation ROC AUC: 0.5018853132233256, Test ROC AUC: 0.5103665291910662, Difference: 0.00848121596774054
#
# n_estimators: 5, max_depth: 20, min_samples_split: 10, min_samples_leaf: 5
# Validation ROC AUC: 0.5049139475845591, Test ROC AUC: 0.4859537486151583, Difference: 0.01896019896940082
#
# n_estimators: 5, max_depth: 20, min_samples_split: 25, min_samples_leaf: 1
# Validation ROC AUC: 0.49220208317777947, Test ROC AUC: 0.5284695521026319, Difference: 0.03626746892485244
#
# n_estimators: 5, max_depth: 20, min_samples_split: 25, min_samples_leaf: 2
# Validation ROC AUC: 0.5157171656835661, Test ROC AUC: 0.49461424594788345, Difference: 0.021102919735682624
#
# n_estimators: 5, max_depth: 20, min_samples_split: 25, min_samples_leaf: 4
# Validation ROC AUC: 0.5208107780183677, Test ROC AUC: 0.5013173452003016, Difference: 0.019493432818066148
#
# n_estimators: 5, max_depth: 20, min_samples_split: 25, min_samples_leaf: 5
# Validation ROC AUC: 0.5115848764279847, Test ROC AUC: 0.49379963319151315, Difference: 0.017785243236471515
#
# n_estimators: 5, max_depth: 30, min_samples_split: 2, min_samples_leaf: 1
# Validation ROC AUC: 0.49976666915552903, Test ROC AUC: 0.4986058484540977, Difference: 0.0011608207014313088
#
# n_estimators: 5, max_depth: 30, min_samples_split: 2, min_samples_leaf: 2
# Validation ROC AUC: 0.
# n_estimators: 200, max_depth: 30, min_samples_split: 5, min_samples_leaf: 2
# Validation ROC AUC: 0.517478813559322, Test ROC AUC: 0.5146700120097194, Difference: 0.002808801549602613
#
# n_estimators: 200, max_depth: 30, min_samples_split: 5, min_samples_leaf: 4
# Validation ROC AUC: 0.512821529903681, Test ROC AUC: 0.5111881243424912, Difference: 0.001633405561189849
#
# n_estimators: 200, max_depth: 30, min_samples_split: 5, min_samples_leaf: 5
# Validation ROC AUC: 0.5124295340849698, Test ROC AUC: 0.5074222859430423, Difference: 0.005007248141927545
#
# n_estimators: 200, max_depth: 30, min_samples_split: 10, min_samples_leaf: 1
# Validation ROC AUC: 0.5214034383633241, Test ROC AUC: 0.5123239272713731, Difference: 0.009079511091951042
#
# n_estimators: 200, max_depth: 30, min_samples_split: 10, min_samples_leaf: 2
# Validation ROC AUC: 0.5190701299186142, Test ROC AUC: 0.5154101458855074, Difference: 0.0036599840331068556
#
# n_estimators: 200, max_depth: 30, min_samples_split: 10, min_samples_leaf: 4
# Validation ROC AUC: 0.5146928432763384, Test ROC AUC: 0.5155404839265265, Difference: 0.0008476406501881639
#
# n_estimators: 200, max_depth: 30, min_samples_split: 10, min_samples_leaf: 5
# Validation ROC AUC: 0.5124295340849698, Test ROC AUC: 0.5074222859430423, Difference: 0.005007248141927545
#
# n_estimators: 200, max_depth: 30, min_samples_split: 25, min_samples_leaf: 1
# Validation ROC AUC: 0.5208714440379303, Test ROC AUC: 0.5142277936562614, Difference: 0.00664365038166892
#
# n_estimators: 200, max_depth: 30, min_samples_split: 25, min_samples_leaf: 2
# Validation ROC AUC: 0.5193594601657583, Test ROC AUC: 0.5143069274668801, Difference: 0.005052532698878176
#
# n_estimators: 200, max_depth: 30, min_samples_split: 25, min_samples_leaf: 4
# Validation ROC AUC: 0.525636059882028, Test ROC AUC: 0.5153635965851433, Difference: 0.010272463296884693
#
# n_estimators: 200, max_depth: 30, min_samples_split: 25, min_samples_leaf: 5
# Validation ROC AUC: 0.5186734674830135, Test ROC AUC: 0.5096519974304786, Difference: 0.009021470052534841
#
# n_estimators: 300, max_depth: None, min_samples_split: 2, min_samples_leaf: 1
# Validation ROC AUC: 0.5175511461211081, Test ROC AUC: 0.5207004738718777, Difference: 0.0031493277507695927
#
# n_estimators: 300, max_depth: None, min_samples_split: 2, min_samples_leaf: 2
# Validation ROC AUC: 0.5179128089300381, Test ROC AUC: 0.5225601184214201, Difference: 0.0046473094913820345
#
# n_estimators: 300, max_depth: None, min_samples_split: 2, min_samples_leaf: 4
# Validation ROC AUC: 0.5133161912939594, Test ROC AUC: 0.5164947445839889, Difference: 0.0031785532900294733
#
# n_estimators: 300, max_depth: None, min_samples_split: 2, min_samples_leaf: 5
# Validation ROC AUC: 0.5157008325244531, Test ROC AUC: 0.5106388425981958, Difference: 0.005061989926257282
#
# n_estimators: 300, max_depth: None, min_samples_split: 5, min_samples_leaf: 1
# Validation ROC AUC: 0.5151221720301651, Test ROC AUC: 0.518072765866329, Difference: 0.0029505938361639172
#
# n_estimators: 300, max_depth: None, min_samples_split: 5, min_samples_leaf: 2
# Validation ROC AUC: 0.5123688680654074, Test ROC AUC: 0.5171231601389031, Difference: 0.004754292073495758
#
# n_estimators: 300, max_depth: None, min_samples_split: 5, min_samples_leaf: 4
# Validation ROC AUC: 0.5133161912939594, Test ROC AUC: 0.5164947445839889, Difference: 0.0031785532900294733
#
# n_estimators: 300, max_depth: None, min_samples_split: 5, min_samples_leaf: 5
# Validation ROC AUC: 0.5157008325244531, Test ROC AUC: 0.5106388425981958, Difference: 0.005061989926257282
#
# n_estimators: 300, max_depth: None, min_samples_split: 10, min_samples_leaf: 1
# Validation ROC AUC: 0.5188134659896961, Test ROC AUC: 0.5219363577965423, Difference: 0.0031228918068462175
#
# n_estimators: 300, max_depth: None, min_samples_split: 10, min_samples_leaf: 2
# Validation ROC AUC: 0.517889475845591, Test ROC AUC: 0.5182636179978215, Difference: 0.0003741421522305277
#
# n_estimators: 300, max_depth: None, min_samples_split: 10, min_samples_leaf: 4
# Validation ROC AUC: 0.515532834316434, Test ROC AUC: 0.5162806178023144, Difference: 0.0007477834858803378
#
# n_estimators: 300, max_depth: None, min_samples_split: 10, min_samples_leaf: 5
# Validation ROC AUC: 0.5157008325244531, Test ROC AUC: 0.5106388425981958, Difference: 0.005061989926257282
#
# n_estimators: 300, max_depth: None, min_samples_split: 25, min_samples_leaf: 1
# Validation ROC AUC: 0.5221267639811842, Test ROC AUC: 0.5161456248312588, Difference: 0.005981139149925374
#
# n_estimators: 300, max_depth: None, min_samples_split: 25, min_samples_leaf: 2
# Validation ROC AUC: 0.5202367841409692, Test ROC AUC: 0.5109739975608167, Difference: 0.009262786580152449
#
# n_estimators: 300, max_depth: None, min_samples_split: 25, min_samples_leaf: 4
# Validation ROC AUC: 0.5232887515866497, Test ROC AUC: 0.5096613072905514, Difference: 0.013627444296098301
#
# n_estimators: 300, max_depth: None, min_samples_split: 25, min_samples_leaf: 5
# Validation ROC AUC: 0.5177448107220189, Test ROC AUC: 0.5128359695753772, Difference: 0.004908841146641696
#
# n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 1
# Validation ROC AUC: 0.5180481408198313, Test ROC AUC: 0.5188408293223352, Difference: 0.0007926885025039132
#
# n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 2
# Validation ROC AUC: 0.5147535092959008, Test ROC AUC: 0.5152611881243425, Difference: 0.0005076788284417155
#
# n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 4
# Validation ROC AUC: 0.5157754983946838, Test ROC AUC: 0.5086884269129435, Difference: 0.00708707148174037
#
# n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 5
# Validation ROC AUC: 0.5200267863809453, Test ROC AUC: 0.5116396525560221, Difference: 0.008387133824923287
#
# n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 1
# Validation ROC AUC: 0.5182254722616293, Test ROC AUC: 0.5161968290616592, Difference: 0.0020286431999700927
#
# n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 2
# Validation ROC AUC: 0.5109688829985813, Test ROC AUC: 0.5120492863992254, Difference: 0.001080403400644081
#
# n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 4
# Validation ROC AUC: 0.5157754983946838, Test ROC AUC: 0.5086884269129435, Difference: 0.00708707148174037
#
# n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 5
# Validation ROC AUC: 0.5200267863809453, Test ROC AUC: 0.5116396525560221, Difference: 0.008387133824923287
#
# n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 1
# Validation ROC AUC: 0.5263033860972149, Test ROC AUC: 0.5185987729604424, Difference: 0.007704613136772509
#
# n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 2
# Validation ROC AUC: 0.5257760583887106, Test ROC AUC: 0.5149632726020128, Difference: 0.010812785786697754
#
# n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 4
# Validation ROC AUC: 0.5120235384155902, Test ROC AUC: 0.5153263571448521, Difference: 0.0033028187292618583
#
# n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 5
# Validation ROC AUC: 0.5200267863809453, Test ROC AUC: 0.5116396525560221, Difference: 0.008387133824923287
#
# n_estimators: 300, max_depth: 10, min_samples_split: 25, min_samples_leaf: 1
# Validation ROC AUC: 0.513754853281565, Test ROC AUC: 0.5148096599108115, Difference: 0.0010548066292465075
#
# n_estimators: 300, max_depth: 10, min_samples_split: 25, min_samples_leaf: 2
# Validation ROC AUC: 0.5150055066079295, Test ROC AUC: 0.519301667395939, Difference: 0.004296160788009429
#
# n_estimators: 300, max_depth: 10, min_samples_split: 25, min_samples_leaf: 4
# Validation ROC AUC: 0.5128075300530128, Test ROC AUC: 0.5174862446817425, Difference: 0.004678714628729708
#
# n_estimators: 300, max_depth: 10, min_samples_split: 25, min_samples_leaf: 5
# Validation ROC AUC: 0.5128961957739118, Test ROC AUC: 0.5142976176068074, Difference: 0.0014014218328955996
#
# n_estimators: 300, max_depth: 20, min_samples_split: 2, min_samples_leaf: 1
# Validation ROC AUC: 0.513899518405137, Test ROC AUC: 0.5225833930716022, Difference: 0.008683874666465141
#
# n_estimators: 300, max_depth: 20, min_samples_split: 2, min_samples_leaf: 2
# Validation ROC AUC: 0.5141468491002762, Test ROC AUC: 0.5193761462765214, Difference: 0.005229297176245207
#
# n_estimators: 300, max_depth: 20, min_samples_split: 2, min_samples_leaf: 4
# Validation ROC AUC: 0.5157801650115732, Test ROC AUC: 0.5194599350171767, Difference: 0.0036797700056034888
#
# n_estimators: 300, max_depth: 20, min_samples_split: 2, min_samples_leaf: 5
# Validation ROC AUC: 0.5172314828641827, Test ROC AUC: 0.5125194343329019, Difference: 0.004712048531280821
#
# n_estimators: 300, max_depth: 20, min_samples_split: 5, min_samples_leaf: 1
# Validation ROC AUC: 0.5139648510415888, Test ROC AUC: 0.5232862875070987, Difference: 0.00932143646550987
#
# n_estimators: 300, max_depth: 20, min_samples_split: 5, min_samples_leaf: 2
# Validation ROC AUC: 0.5150288396923766, Test ROC AUC: 0.5154566951858713, Difference: 0.0004278554934947776
#
# n_estimators: 300, max_depth: 20, min_samples_split: 5, min_samples_leaf: 4
# Validation ROC AUC: 0.5157801650115732, Test ROC AUC: 0.5194599350171767, Difference: 0.0036797700056034888
#
# n_estimators: 300, max_depth: 20, min_samples_split: 5, min_samples_leaf: 5
# Validation ROC AUC: 0.5172314828641827, Test ROC AUC: 0.5125194343329019, Difference: 0.004712048531280821
#
# n_estimators: 300, max_depth: 20, min_samples_split: 10, min_samples_leaf: 1
# Validation ROC AUC: 0.5186641342492346, Test ROC AUC: 0.5223459916397456, Difference: 0.0036818573905109675
#
# n_estimators: 300, max_depth: 20, min_samples_split: 10, min_samples_leaf: 2
# Validation ROC AUC: 0.5158501642649145, Test ROC AUC: 0.5142557232364798, Difference: 0.0015944410284346455
#
# n_estimators: 300, max_depth: 20, min_samples_split: 10, min_samples_leaf: 4
# Validation ROC AUC: 0.5128681960725752, Test ROC AUC: 0.5142417584463705, Difference: 0.0013735623737953784
#
# n_estimators: 300, max_depth: 20, min_samples_split: 10, min_samples_leaf: 5
# Validation ROC AUC: 0.5172314828641827, Test ROC AUC: 0.5125194343329019, Difference: 0.004712048531280821
#
# n_estimators: 300, max_depth: 20, min_samples_split: 25, min_samples_leaf: 1
# Validation ROC AUC: 0.5163961584409766, Test ROC AUC: 0.5153496317950341, Difference: 0.0010465266459425138
#
# n_estimators: 300, max_depth: 20, min_samples_split: 25, min_samples_leaf: 2
# Validation ROC AUC: 0.5224254274621071, Test ROC AUC: 0.5135574837310195, Difference: 0.008867943731087569
#
# n_estimators: 300, max_depth: 20, min_samples_split: 25, min_samples_leaf: 4
# Validation ROC AUC: 0.5173201485850817, Test ROC AUC: 0.5166530122052265, Difference: 0.0006671363798551599
#
# n_estimators: 300, max_depth: 20, min_samples_split: 25, min_samples_leaf: 5
# Validation ROC AUC: 0.5202414507578587, Test ROC AUC: 0.511881708917915, Difference: 0.008359741839943702
#
# n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 1
# Validation ROC AUC: 0.518234805495408, Test ROC AUC: 0.5195763082680868, Difference: 0.0013415027726787487
#
# n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 2
# Validation ROC AUC: 0.5190094638990518, Test ROC AUC: 0.5192597730256114, Difference: 0.00025030912655965576
#
# n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 4
# Validation ROC AUC: 0.5157754983946837, Test ROC AUC: 0.5158197797287107, Difference: 4.4281334027007624e-05
#
# n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 5
# Validation ROC AUC: 0.5127515306503397, Test ROC AUC: 0.5089351382048728, Difference: 0.003816392445466943
#
# n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 1
# Validation ROC AUC: 0.5190701299186142, Test ROC AUC: 0.5170347164682114, Difference: 0.002035413450402812
#
# n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 2
# Validation ROC AUC: 0.5151268386470544, Test ROC AUC: 0.5145210542485547, Difference: 0.0006057843984997868
#
# n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 4
# Validation ROC AUC: 0.5157754983946837, Test ROC AUC: 0.5158197797287107, Difference: 4.4281334027007624e-05
#
# n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 5
# Validation ROC AUC: 0.5127515306503397, Test ROC AUC: 0.5089351382048728, Difference: 0.003816392445466943
#
# n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 1
# Validation ROC AUC: 0.520334783095647, Test ROC AUC: 0.516275962872278, Difference: 0.0040588202233690085
#
# n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 2
# Validation ROC AUC: 0.5178521429104755, Test ROC AUC: 0.5189246180629905, Difference: 0.0010724751525149623
#
# n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 4
# Validation ROC AUC: 0.5131108601508251, Test ROC AUC: 0.515335667004925, Difference: 0.00222480685409987
#
# n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 5
# Validation ROC AUC: 0.5127515306503397, Test ROC AUC: 0.5089351382048728, Difference: 0.003816392445466943
#
# n_estimators: 300, max_depth: 30, min_samples_split: 25, min_samples_leaf: 1
# Validation ROC AUC: 0.5184074703203165, Test ROC AUC: 0.5145815683390278, Difference: 0.0038259019812887374
#
# n_estimators: 300, max_depth: 30, min_samples_split: 25, min_samples_leaf: 2
# Validation ROC AUC: 0.5188927984768162, Test ROC AUC: 0.5126451174438847, Difference: 0.006247681032931496
#
# n_estimators: 300, max_depth: 30, min_samples_split: 25, min_samples_leaf: 4
# Validation ROC AUC: 0.5226214253714627, Test ROC AUC: 0.5108762440300523, Difference: 0.011745181341410449
#
# n_estimators: 300, max_depth: 30, min_samples_split: 25, min_samples_leaf: 5
# Validation ROC AUC: 0.5194387926528783, Test ROC AUC: 0.5087675607235622, Difference: 0.010671231929316072
#
#
# Best parameters based on smallest ROC AUC difference:
# n_estimators               10
# max_depth                None
# min_samples_split           2
# min_samples_leaf            1
# roc_auc_val          0.502973
# roc_auc_test         0.503014
# roc_auc_diff         0.000041
# Name: 64, dtype: object
