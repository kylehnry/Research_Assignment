# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score
from sklearn.model_selection import ParameterGrid

# Load the dataset
train_data = pd.read_csv('train_data.csv')
val_data = pd.read_csv('val_data.csv')
test_data = pd.read_csv('test_data.csv')

# Ensure the data is sorted by the 'Entry_Date' column
train_data['Entry_Date'] = pd.to_datetime(train_data['Entry_Date'])
val_data['Entry_Date'] = pd.to_datetime(val_data['Entry_Date'])
test_data['Entry_Date'] = pd.to_datetime(test_data['Entry_Date'])

train_data = train_data.sort_values(by='Entry_Date')
val_data = val_data.sort_values(by='Entry_Date')
test_data = test_data.sort_values(by='Entry_Date')

# Define the feature sets manually
selected_features = ['SMA5_At_Entry', 'SMA10_At_Entry', 'EMA5_At_Entry', 'EMA15_At_Entry', 'RSI5_At_Entry', 'RSI10_At_Entry',
                     'ATR5_At_Entry', 'ATR15_At_Entry', 'Stoch7_K_At_Entry', 'Stoch21_K_At_Entry',
                     'BB10_High_At_Entry', 'BB10_Low_At_Entry', 'BB10_MAvg_At_Entry', 
                     'BB15_High_At_Entry', 'BB15_Low_At_Entry', 'BB15_MAvg_At_Entry', 
                     'Open', 'High', 'Low', 'Last', 'MACD_At_Entry', 'Day_Of_Week_At_Entry',
                     'ROC14_At_Entry' , 'ROC15_At_Entry'
                     ]

# Separating features and target variable
X_train = train_data[selected_features]
y_train = train_data['Target']
X_val = val_data[selected_features]
y_val = val_data['Target']
X_test = test_data[selected_features]
y_test = test_data['Target']

# Define parameter grid for Random Forest
param_grid = {
    'n_estimators': [5, 10, 20],
    'max_depth': [None, 10, 20],
    'min_samples_split': [10, 25, 50],
    'min_samples_leaf': [5, 10, 20],
    'bootstrap': [True, False]
}

# Initialize a list to store results
results = []

# Perform grid search
for i, params in enumerate(ParameterGrid(param_grid)):
    rf_clf = RandomForestClassifier(**params, random_state=42)
    
    # Fit the model to the training data
    rf_clf.fit(X_train, y_train)
    
    # Predict on the validation set
    y_val_pred = rf_clf.predict(X_val)
    
    # Calculate evaluation metrics for the validation set
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_roc_auc = roc_auc_score(y_val, y_val_pred)
    
    # Predict on the test set
    y_test_pred = rf_clf.predict(X_test)
    
    # Calculate evaluation metrics for the test set
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_roc_auc = roc_auc_score(y_test, y_test_pred)
    
    # Store the results
    results.append({
        'params': params,
        'val_accuracy': val_accuracy,
        'val_roc_auc': val_roc_auc,
        'test_accuracy': test_accuracy,
        'test_roc_auc': test_roc_auc
    })
    
    # Save results to a CSV file every ten iterations
    if (i + 1) % 10 == 0:
        results_df = pd.DataFrame(results)
        results_df.to_csv('grid_search_results.csv', index=False)
    
    # Print the current results
    print(f"Iteration: {i + 1}")
    print(f"Params: {params}")
    print(f"Validation Accuracy: {val_accuracy}")
    print(f"Validation ROC AUC: {val_roc_auc}")
    print(f"Test Accuracy: {test_accuracy}")
    print(f"Test ROC AUC: {test_roc_auc}")
    print("-" * 60)

# Final save after all iterations
results_df = pd.DataFrame(results)
results_df.to_csv('grid_search_results_retest.csv', index=False)

# Display the final results
print("Final Results:")
print(results_df)
# Out:
# Iteration: 1
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5226781857451404
# Validation ROC AUC: 0.5229177555439409
# Test Accuracy: 0.5210355987055016
# Test ROC AUC: 0.5209751147440255
# ------------------------------------------------------------
# Iteration: 2
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5432968715000374
# Test Accuracy: 0.5285868392664509
# Test ROC AUC: 0.5284043830821222
# ------------------------------------------------------------
# Iteration: 3
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5269978401727862
# Validation ROC AUC: 0.5267770477114911
# Test Accuracy: 0.5329018338727076
# Test ROC AUC: 0.5327893271764125
# ------------------------------------------------------------
# Iteration: 4
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5237580993520519
# Validation ROC AUC: 0.5239770775778392
# Test Accuracy: 0.5221143473570659
# Test ROC AUC: 0.522117900067962
# ------------------------------------------------------------
# Iteration: 5
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5205183585313174
# Validation ROC AUC: 0.520841111028149
# Test Accuracy: 0.5210355987055016
# Test ROC AUC: 0.5210798506698444
# ------------------------------------------------------------
# Iteration: 6
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5496760259179265
# Validation ROC AUC: 0.5497788023594414
# Test Accuracy: 0.5318230852211435
# Test ROC AUC: 0.531762915103386
# ------------------------------------------------------------
# Iteration: 7
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5356371490280778
# Validation ROC AUC: 0.5357976181587396
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5350632604991947
# ------------------------------------------------------------
# Iteration: 8
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5433808706040468
# Test Accuracy: 0.5361380798274002
# Test ROC AUC: 0.5361129472224032
# ------------------------------------------------------------
# Iteration: 9
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5442764578833693
# Validation ROC AUC: 0.5443981930859405
# Test Accuracy: 0.5329018338727076
# Test ROC AUC: 0.5328707884520496
# ------------------------------------------------------------
# Iteration: 10
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.4956803455723542
# Validation ROC AUC: 0.4960147091764355
# Test Accuracy: 0.5221143473570659
# Test ROC AUC: 0.522048076117416
# ------------------------------------------------------------
# Iteration: 11
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5086393088552916
# Validation ROC AUC: 0.5090205704472486
# Test Accuracy: 0.5372168284789643
# Test ROC AUC: 0.5371626339456117
# ------------------------------------------------------------
# Iteration: 12
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5259179265658748
# Validation ROC AUC: 0.5261797207496453
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5307481403554505
# ------------------------------------------------------------
# Iteration: 13
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5377969762419006
# Validation ROC AUC: 0.5380842604345554
# Test Accuracy: 0.4994606256742179
# Test ROC AUC: 0.49952752460130523
# ------------------------------------------------------------
# Iteration: 14
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5509641230493542
# Test Accuracy: 0.5339805825242718
# Test ROC AUC: 0.5339902991258042
# ------------------------------------------------------------
# Iteration: 15
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5377969762419006
# Validation ROC AUC: 0.5382522586425744
# Test Accuracy: 0.5285868392664509
# Test ROC AUC: 0.5286022176086693
# ------------------------------------------------------------
# Iteration: 16
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5237580993520519
# Validation ROC AUC: 0.5242290748898678
# Test Accuracy: 0.5296655879180151
# Test ROC AUC: 0.5296519043318779
# ------------------------------------------------------------
# Iteration: 17
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5345572354211663
# Validation ROC AUC: 0.5346542970208318
# Test Accuracy: 0.5436893203883495
# Test ROC AUC: 0.5436702261365011
# ------------------------------------------------------------
# Iteration: 18
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5615550755939525
# Validation ROC AUC: 0.561767341148361
# Test Accuracy: 0.5339805825242718
# Test ROC AUC: 0.5340019364508951
# ------------------------------------------------------------
# Iteration: 19
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5453563714902808
# Validation ROC AUC: 0.545037519599791
# Test Accuracy: 0.5663430420711975
# Test ROC AUC: 0.5662373269529759
# ------------------------------------------------------------
# Iteration: 20
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.541036717062635
# Validation ROC AUC: 0.541136227880236
# Test Accuracy: 0.5609492988133765
# Test ROC AUC: 0.5608725200860232
# ------------------------------------------------------------
# Iteration: 21
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5506701261853207
# Test Accuracy: 0.5426105717367853
# Test ROC AUC: 0.5425856274380195
# ------------------------------------------------------------
# Iteration: 22
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5453563714902808
# Validation ROC AUC: 0.545037519599791
# Test Accuracy: 0.5663430420711975
# Test ROC AUC: 0.5662373269529759
# ------------------------------------------------------------
# Iteration: 23
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.541036717062635
# Validation ROC AUC: 0.541136227880236
# Test Accuracy: 0.5609492988133765
# Test ROC AUC: 0.5608725200860232
# ------------------------------------------------------------
# Iteration: 24
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5506701261853207
# Test Accuracy: 0.5426105717367853
# Test ROC AUC: 0.5425856274380195
# ------------------------------------------------------------
# Iteration: 25
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5367170626349892
# Validation ROC AUC: 0.536646942432614
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5307365030303595
# ------------------------------------------------------------
# Iteration: 26
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5377969762419006
# Validation ROC AUC: 0.5374962667064884
# Test Accuracy: 0.5382955771305286
# Test ROC AUC: 0.5382239579939114
# ------------------------------------------------------------
# Iteration: 27
# Params: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5507541252893302
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5349468872482847
# ------------------------------------------------------------
# Iteration: 28
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5183585313174947
# Validation ROC AUC: 0.5185124692003286
# Test Accuracy: 0.5382955771305286
# Test ROC AUC: 0.5383519685699124
# ------------------------------------------------------------
# Iteration: 29
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.550418128873292
# Test Accuracy: 0.5501618122977346
# Test ROC AUC: 0.5499799838008435
# ------------------------------------------------------------
# Iteration: 30
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5572354211663066
# Validation ROC AUC: 0.5566060628686628
# Test Accuracy: 0.5533980582524272
# Test ROC AUC: 0.5531872305959241
# ------------------------------------------------------------
# Iteration: 31
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5424988800119465
# Test Accuracy: 0.5490830636461704
# Test ROC AUC: 0.5489652090529079
# ------------------------------------------------------------
# Iteration: 32
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5432968715000374
# Test Accuracy: 0.5555555555555556
# Test ROC AUC: 0.5554262519434333
# ------------------------------------------------------------
# Iteration: 33
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5453563714902808
# Validation ROC AUC: 0.5450795191517956
# Test Accuracy: 0.540453074433657
# Test ROC AUC: 0.5402884194650555
# ------------------------------------------------------------
# Iteration: 34
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5399568034557235
# Validation ROC AUC: 0.539446912566266
# Test Accuracy: 0.552319309600863
# Test ROC AUC: 0.5521026318974426
# ------------------------------------------------------------
# Iteration: 35
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5356371490280778
# Validation ROC AUC: 0.5353776226386918
# Test Accuracy: 0.5706580366774542
# Test ROC AUC: 0.5705524470967202
# ------------------------------------------------------------
# Iteration: 36
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5496760259179265
# Validation ROC AUC: 0.5492748077353842
# Test Accuracy: 0.5663430420711975
# Test ROC AUC: 0.5660860417267928
# ------------------------------------------------------------
# Iteration: 37
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5302375809935205
# Validation ROC AUC: 0.5300810124692004
# Test Accuracy: 0.5339805825242718
# Test ROC AUC: 0.533804101924348
# ------------------------------------------------------------
# Iteration: 38
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5475161987041036
# Validation ROC AUC: 0.5474081609796162
# Test Accuracy: 0.5512405609492989
# Test ROC AUC: 0.5510762198244161
# ------------------------------------------------------------
# Iteration: 39
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5485961123110151
# Validation ROC AUC: 0.5482574852534907
# Test Accuracy: 0.552319309600863
# Test ROC AUC: 0.5521375438727156
# ------------------------------------------------------------
# Iteration: 40
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5604751619870411
# Validation ROC AUC: 0.5597840289703576
# Test Accuracy: 0.5469255663430421
# Test ROC AUC: 0.5468076489810358
# ------------------------------------------------------------
# Iteration: 41
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5442764578833693
# Validation ROC AUC: 0.5433062047338162
# Test Accuracy: 0.5533980582524272
# Test ROC AUC: 0.5531988679210151
# ------------------------------------------------------------
# Iteration: 42
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5637149028077754
# Validation ROC AUC: 0.5630879937280668
# Test Accuracy: 0.5490830636461704
# Test ROC AUC: 0.5489535717278169
# ------------------------------------------------------------
# Iteration: 43
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5637149028077754
# Validation ROC AUC: 0.5635919883521242
# Test Accuracy: 0.5469255663430421
# Test ROC AUC: 0.5469240222319459
# ------------------------------------------------------------
# Iteration: 44
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5475161987041036
# Validation ROC AUC: 0.5471561636675876
# Test Accuracy: 0.5533980582524272
# Test ROC AUC: 0.5532337798962882
# ------------------------------------------------------------
# Iteration: 45
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5518358531317494
# Validation ROC AUC: 0.551351452251176
# Test Accuracy: 0.56957928802589
# Test ROC AUC: 0.5693514751473285
# ------------------------------------------------------------
# Iteration: 46
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5367170626349892
# Validation ROC AUC: 0.5370669379526618
# Test Accuracy: 0.5458468176914779
# Test ROC AUC: 0.5457695995829183
# ------------------------------------------------------------
# Iteration: 47
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5507541252893302
# Test Accuracy: 0.5469255663430421
# Test ROC AUC: 0.5467727370057628
# ------------------------------------------------------------
# Iteration: 48
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.550418128873292
# Test Accuracy: 0.5587918015102481
# Test ROC AUC: 0.558621861413423
# ------------------------------------------------------------
# Iteration: 49
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5367170626349892
# Validation ROC AUC: 0.5370669379526618
# Test Accuracy: 0.5458468176914779
# Test ROC AUC: 0.5457695995829183
# ------------------------------------------------------------
# Iteration: 50
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5507541252893302
# Test Accuracy: 0.5469255663430421
# Test ROC AUC: 0.5467727370057628
# ------------------------------------------------------------
# Iteration: 51
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.550418128873292
# Test Accuracy: 0.5587918015102481
# Test ROC AUC: 0.558621861413423
# ------------------------------------------------------------
# Iteration: 52
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5464362850971922
# Validation ROC AUC: 0.547272829089823
# Test Accuracy: 0.5501618122977346
# Test ROC AUC: 0.5502476422779365
# ------------------------------------------------------------
# Iteration: 53
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5464362850971922
# Validation ROC AUC: 0.546726834913761
# Test Accuracy: 0.5469255663430421
# Test ROC AUC: 0.5468425609563088
# ------------------------------------------------------------
# Iteration: 54
# Params: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5505441275293064
# Test Accuracy: 0.5458468176914779
# Test ROC AUC: 0.5456881383072811
# ------------------------------------------------------------
# Iteration: 55
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5075593952483801
# Validation ROC AUC: 0.50707925782125
# Test Accuracy: 0.5091693635382956
# Test ROC AUC: 0.5090910783610922
# ------------------------------------------------------------
# Iteration: 56
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5183585313174947
# Validation ROC AUC: 0.5186384678563428
# Test Accuracy: 0.5026968716289104
# Test ROC AUC: 0.5027231340712949
# ------------------------------------------------------------
# Iteration: 57
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5140388768898488
# Validation ROC AUC: 0.5140651833047114
# Test Accuracy: 0.5124056094929881
# Test ROC AUC: 0.5123565117816279
# ------------------------------------------------------------
# Iteration: 58
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5442764578833693
# Validation ROC AUC: 0.5439361980138878
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5273779710090958
# ------------------------------------------------------------
# Iteration: 59
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5464362850971922
# Validation ROC AUC: 0.546306839393713
# Test Accuracy: 0.5339805825242718
# Test ROC AUC: 0.5339321125003491
# ------------------------------------------------------------
# Iteration: 60
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5496760259179265
# Validation ROC AUC: 0.549484805495408
# Test Accuracy: 0.5426105717367853
# Test ROC AUC: 0.5425739901129286
# ------------------------------------------------------------
# Iteration: 61
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5561555075593952
# Validation ROC AUC: 0.5561767341148361
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5348887006228296
# ------------------------------------------------------------
# Iteration: 62
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5436328679160757
# Test Accuracy: 0.552319309600863
# Test ROC AUC: 0.5521259065476246
# ------------------------------------------------------------
# Iteration: 63
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5496760259179265
# Validation ROC AUC: 0.5496528037034271
# Test Accuracy: 0.5318230852211435
# Test ROC AUC: 0.5316116298772029
# ------------------------------------------------------------
# Iteration: 64
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5259179265658748
# Validation ROC AUC: 0.525675726125588
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5306666790798135
# ------------------------------------------------------------
# Iteration: 65
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5367170626349892
# Validation ROC AUC: 0.5367729410886284
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5306317671045405
# ------------------------------------------------------------
# Iteration: 66
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.531317494600432
# Validation ROC AUC: 0.5315183304711417
# Test Accuracy: 0.5436893203883495
# Test ROC AUC: 0.5436120395110461
# ------------------------------------------------------------
# Iteration: 67
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5356371490280778
# Validation ROC AUC: 0.5357556186067349
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5306550417547223
# ------------------------------------------------------------
# Iteration: 68
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5442764578833693
# Validation ROC AUC: 0.5445661912939596
# Test Accuracy: 0.5480043149946062
# Test ROC AUC: 0.5479620716300634
# ------------------------------------------------------------
# Iteration: 69
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5356371490280778
# Validation ROC AUC: 0.5356716195027252
# Test Accuracy: 0.5533980582524272
# Test ROC AUC: 0.5533734277973802
# ------------------------------------------------------------
# Iteration: 70
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5248380129589633
# Validation ROC AUC: 0.5248264018517137
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5306084924543584
# ------------------------------------------------------------
# Iteration: 71
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.531317494600432
# Validation ROC AUC: 0.5311823340551035
# Test Accuracy: 0.5382955771305286
# Test ROC AUC: 0.5382123206688203
# ------------------------------------------------------------
# Iteration: 72
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5561555075593952
# Validation ROC AUC: 0.5563027327708504
# Test Accuracy: 0.540453074433657
# Test ROC AUC: 0.5403698807406925
# ------------------------------------------------------------
# Iteration: 73
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5512581199133877
# Test Accuracy: 0.552319309600863
# Test ROC AUC: 0.5523470157243536
# ------------------------------------------------------------
# Iteration: 74
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.531317494600432
# Validation ROC AUC: 0.5313923318151274
# Test Accuracy: 0.5501618122977346
# Test ROC AUC: 0.5500381704262984
# ------------------------------------------------------------
# Iteration: 75
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5539956803455723
# Validation ROC AUC: 0.5541000895990442
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5349934365486486
# ------------------------------------------------------------
# Iteration: 76
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5512581199133877
# Test Accuracy: 0.552319309600863
# Test ROC AUC: 0.5523470157243536
# ------------------------------------------------------------
# Iteration: 77
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.531317494600432
# Validation ROC AUC: 0.5313923318151274
# Test Accuracy: 0.5501618122977346
# Test ROC AUC: 0.5500381704262984
# ------------------------------------------------------------
# Iteration: 78
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5539956803455723
# Validation ROC AUC: 0.5541000895990442
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5349934365486486
# ------------------------------------------------------------
# Iteration: 79
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5302375809935205
# Validation ROC AUC: 0.5303750093332338
# Test Accuracy: 0.5134843581445523
# Test ROC AUC: 0.5136156703564746
# ------------------------------------------------------------
# Iteration: 80
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5377969762419006
# Validation ROC AUC: 0.5377062644665123
# Test Accuracy: 0.5436893203883495
# Test ROC AUC: 0.5436353141612282
# ------------------------------------------------------------
# Iteration: 81
# Params: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.541036717062635
# Validation ROC AUC: 0.5409682296722168
# Test Accuracy: 0.5382955771305286
# Test ROC AUC: 0.5382239579939114
# ------------------------------------------------------------
# Iteration: 82
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5291576673866091
# Validation ROC AUC: 0.5295256850593594
# Test Accuracy: 0.5296655879180151
# Test ROC AUC: 0.5296751789820598
# ------------------------------------------------------------
# Iteration: 83
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5226781857451404
# Validation ROC AUC: 0.522875755991936
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5275874428607339
# ------------------------------------------------------------
# Iteration: 84
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5323974082073434
# Validation ROC AUC: 0.5329136489210782
# Test Accuracy: 0.5361380798274002
# Test ROC AUC: 0.5362176831482223
# ------------------------------------------------------------
# Iteration: 85
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5043196544276458
# Validation ROC AUC: 0.5045312849996267
# Test Accuracy: 0.5361380798274002
# Test ROC AUC: 0.5361711338478583
# ------------------------------------------------------------
# Iteration: 86
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5302375809935205
# Validation ROC AUC: 0.530333009781229
# Test Accuracy: 0.5318230852211435
# Test ROC AUC: 0.5319025630044781
# ------------------------------------------------------------
# Iteration: 87
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5291576673866091
# Validation ROC AUC: 0.5293576868513402
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5275408935603698
# ------------------------------------------------------------
# Iteration: 88
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.519438444924406
# Validation ROC AUC: 0.5196977898902411
# Test Accuracy: 0.511326860841424
# Test ROC AUC: 0.5111904518075093
# ------------------------------------------------------------
# Iteration: 89
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5302375809935205
# Validation ROC AUC: 0.5307530053012768
# Test Accuracy: 0.5393743257820928
# Test ROC AUC: 0.5393551059927569
# ------------------------------------------------------------
# Iteration: 90
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.531317494600432
# Validation ROC AUC: 0.5316443291271559
# Test Accuracy: 0.5296655879180151
# Test ROC AUC: 0.5296519043318779
# ------------------------------------------------------------
# Iteration: 91
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5129589632829373
# Validation ROC AUC: 0.51359385499888
# Test Accuracy: 0.5156418554476807
# Test ROC AUC: 0.5157034064778006
# ------------------------------------------------------------
# Iteration: 92
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5291576673866091
# Validation ROC AUC: 0.5292316881953258
# Test Accuracy: 0.517799352750809
# Test ROC AUC: 0.5178027799242177
# ------------------------------------------------------------
# Iteration: 93
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5421166306695464
# Validation ROC AUC: 0.5419435526021055
# Test Accuracy: 0.5426105717367853
# Test ROC AUC: 0.5426205394132927
# ------------------------------------------------------------
# Iteration: 94
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5043196544276458
# Validation ROC AUC: 0.5045732845516315
# Test Accuracy: 0.5026968716289104
# Test ROC AUC: 0.502734771396386
# ------------------------------------------------------------
# Iteration: 95
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.509719222462203
# Validation ROC AUC: 0.5102058911371612
# Test Accuracy: 0.5134843581445523
# Test ROC AUC: 0.5134643851302916
# ------------------------------------------------------------
# Iteration: 96
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5248380129589633
# Validation ROC AUC: 0.5250363996117374
# Test Accuracy: 0.5156418554476807
# Test ROC AUC: 0.5156684945025276
# ------------------------------------------------------------
# Iteration: 97
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5515521167774211
# Test Accuracy: 0.5145631067961165
# Test ROC AUC: 0.5145140718535001
# ------------------------------------------------------------
# Iteration: 98
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5345572354211663
# Validation ROC AUC: 0.5354102889569178
# Test Accuracy: 0.5145631067961165
# Test ROC AUC: 0.5146537197545922
# ------------------------------------------------------------
# Iteration: 99
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5453563714902808
# Validation ROC AUC: 0.545793511535877
# Test Accuracy: 0.5285868392664509
# Test ROC AUC: 0.5285556683083054
# ------------------------------------------------------------
# Iteration: 100
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5442764578833693
# Validation ROC AUC: 0.54448219218995
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5275059815850968
# ------------------------------------------------------------
# Iteration: 101
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5475161987041036
# Validation ROC AUC: 0.5482481520197118
# Test Accuracy: 0.5188781014023732
# Test ROC AUC: 0.5189688398983364
# ------------------------------------------------------------
# Iteration: 102
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5367170626349892
# Validation ROC AUC: 0.5370249384006571
# Test Accuracy: 0.52319309600863
# Test ROC AUC: 0.5232374107417165
# ------------------------------------------------------------
# Iteration: 103
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5442764578833693
# Validation ROC AUC: 0.54448219218995
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5275059815850968
# ------------------------------------------------------------
# Iteration: 104
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5475161987041036
# Validation ROC AUC: 0.5482481520197118
# Test Accuracy: 0.5188781014023732
# Test ROC AUC: 0.5189688398983364
# ------------------------------------------------------------
# Iteration: 105
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5367170626349892
# Validation ROC AUC: 0.5370249384006571
# Test Accuracy: 0.52319309600863
# Test ROC AUC: 0.5232374107417165
# ------------------------------------------------------------
# Iteration: 106
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.550755939524838
# Validation ROC AUC: 0.5510481221533637
# Test Accuracy: 0.5415318230852212
# Test ROC AUC: 0.5415592153649931
# ------------------------------------------------------------
# Iteration: 107
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5302375809935205
# Validation ROC AUC: 0.5305430075412528
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5275525308854608
# ------------------------------------------------------------
# Iteration: 108
# Params: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5205183585313174
# Validation ROC AUC: 0.5207991114761442
# Test Accuracy: 0.5458468176914779
# Test ROC AUC: 0.5458976101589194
# ------------------------------------------------------------
# Iteration: 109
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5421166306695464
# Validation ROC AUC: 0.5415655566340626
# Test Accuracy: 0.5480043149946062
# Test ROC AUC: 0.5477409624533343
# ------------------------------------------------------------
# Iteration: 110
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5464362850971922
# Validation ROC AUC: 0.5460128425296797
# Test Accuracy: 0.5393743257820928
# Test ROC AUC: 0.5391223594909369
# ------------------------------------------------------------
# Iteration: 111
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5572354211663066
# Validation ROC AUC: 0.5568580601806914
# Test Accuracy: 0.5490830636461704
# Test ROC AUC: 0.5488604731270889
# ------------------------------------------------------------
# Iteration: 112
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5388768898488121
# Validation ROC AUC: 0.5383455909803629
# Test Accuracy: 0.5329018338727076
# Test ROC AUC: 0.5325449433495015
# ------------------------------------------------------------
# Iteration: 113
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5485961123110151
# Validation ROC AUC: 0.548173486149481
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5347374153966467
# ------------------------------------------------------------
# Iteration: 114
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5496760259179265
# Validation ROC AUC: 0.5490648099753603
# Test Accuracy: 0.5533980582524272
# Test ROC AUC: 0.5531174066453781
# ------------------------------------------------------------
# Iteration: 115
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5367170626349892
# Validation ROC AUC: 0.5366049428806092
# Test Accuracy: 0.5436893203883495
# Test ROC AUC: 0.5435305782354091
# ------------------------------------------------------------
# Iteration: 116
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5429608750839992
# Test Accuracy: 0.552319309600863
# Test ROC AUC: 0.5521491811978066
# ------------------------------------------------------------
# Iteration: 117
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5496760259179265
# Validation ROC AUC: 0.5490228104233555
# Test Accuracy: 0.5577130528586839
# Test ROC AUC: 0.5575139880647595
# ------------------------------------------------------------
# Iteration: 118
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5518358531317494
# Validation ROC AUC: 0.5522334428432764
# Test Accuracy: 0.5490830636461704
# Test ROC AUC: 0.549058307653636
# ------------------------------------------------------------
# Iteration: 119
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5485961123110151
# Validation ROC AUC: 0.548761479877548
# Test Accuracy: 0.5469255663430421
# Test ROC AUC: 0.5468309236312178
# ------------------------------------------------------------
# Iteration: 120
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5475161987041036
# Validation ROC AUC: 0.5473241618756066
# Test Accuracy: 0.552319309600863
# Test ROC AUC: 0.5521724558479886
# ------------------------------------------------------------
# Iteration: 121
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5421166306695464
# Validation ROC AUC: 0.5419015530501008
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5349585245733756
# ------------------------------------------------------------
# Iteration: 122
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5356371490280778
# Validation ROC AUC: 0.5357556186067349
# Test Accuracy: 0.5587918015102481
# Test ROC AUC: 0.558668410713787
# ------------------------------------------------------------
# Iteration: 123
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5334773218142549
# Validation ROC AUC: 0.5333849772269096
# Test Accuracy: 0.5598705501618123
# Test ROC AUC: 0.5597762840624505
# ------------------------------------------------------------
# Iteration: 124
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5453563714902808
# Validation ROC AUC: 0.5449535204957815
# Test Accuracy: 0.511326860841424
# Test ROC AUC: 0.5111206278569633
# ------------------------------------------------------------
# Iteration: 125
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5464362850971922
# Validation ROC AUC: 0.546138841185694
# Test Accuracy: 0.5296655879180151
# Test ROC AUC: 0.5295820803813318
# ------------------------------------------------------------
# Iteration: 126
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5475161987041036
# Validation ROC AUC: 0.5469461659075636
# Test Accuracy: 0.540453074433657
# Test ROC AUC: 0.5403000567901465
# ------------------------------------------------------------
# Iteration: 127
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5464362850971922
# Validation ROC AUC: 0.5466008362577466
# Test Accuracy: 0.5339805825242718
# Test ROC AUC: 0.533873925874894
# ------------------------------------------------------------
# Iteration: 128
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5539956803455723
# Validation ROC AUC: 0.5537640931830061
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5272965097334588
# ------------------------------------------------------------
# Iteration: 129
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5428348764279848
# Test Accuracy: 0.5469255663430421
# Test ROC AUC: 0.5466680010799438
# ------------------------------------------------------------
# Iteration: 130
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5464362850971922
# Validation ROC AUC: 0.5466008362577466
# Test Accuracy: 0.5339805825242718
# Test ROC AUC: 0.533873925874894
# ------------------------------------------------------------
# Iteration: 131
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5539956803455723
# Validation ROC AUC: 0.5537640931830061
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5272965097334588
# ------------------------------------------------------------
# Iteration: 132
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5428348764279848
# Test Accuracy: 0.5469255663430421
# Test ROC AUC: 0.5466680010799438
# ------------------------------------------------------------
# Iteration: 133
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5356371490280778
# Validation ROC AUC: 0.5354196221906967
# Test Accuracy: 0.540453074433657
# Test ROC AUC: 0.5403000567901465
# ------------------------------------------------------------
# Iteration: 134
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5356371490280778
# Validation ROC AUC: 0.5352936235346822
# Test Accuracy: 0.5361380798274002
# Test ROC AUC: 0.5360663979220393
# ------------------------------------------------------------
# Iteration: 135
# Params: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5442764578833693
# Validation ROC AUC: 0.5436002015978496
# Test Accuracy: 0.5490830636461704
# Test ROC AUC: 0.548930297077635
# ------------------------------------------------------------
# Iteration: 136
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5334773218142549
# Validation ROC AUC: 0.533510975882924
# Test Accuracy: 0.5264293419633226
# Test ROC AUC: 0.5264795695120703
# ------------------------------------------------------------
# Iteration: 137
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5226781857451404
# Validation ROC AUC: 0.5227497573359218
# Test Accuracy: 0.5382955771305286
# Test ROC AUC: 0.5384101551953674
# ------------------------------------------------------------
# Iteration: 138
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5464362850971922
# Validation ROC AUC: 0.5466008362577466
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5308528762812694
# ------------------------------------------------------------
# Iteration: 139
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5259179265658748
# Validation ROC AUC: 0.526431718061674
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5352029084002867
# ------------------------------------------------------------
# Iteration: 140
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5280777537796977
# Validation ROC AUC: 0.5287603598894945
# Test Accuracy: 0.535059331175836
# Test ROC AUC: 0.5352261830504687
# ------------------------------------------------------------
# Iteration: 141
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5345572354211663
# Validation ROC AUC: 0.5349062943328604
# Test Accuracy: 0.5242718446601942
# Test ROC AUC: 0.5243336467652892
# ------------------------------------------------------------
# Iteration: 142
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5302375809935205
# Validation ROC AUC: 0.5303750093332338
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5307830523307234
# ------------------------------------------------------------
# Iteration: 143
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5345572354211663
# Validation ROC AUC: 0.5350322929888748
# Test Accuracy: 0.5124056094929881
# Test ROC AUC: 0.5124263357321739
# ------------------------------------------------------------
# Iteration: 144
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5356371490280778
# Validation ROC AUC: 0.5359656163667588
# Test Accuracy: 0.5242718446601942
# Test ROC AUC: 0.5242405481645611
# ------------------------------------------------------------
# Iteration: 145
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.5388768898488121
# Validation ROC AUC: 0.5393955797804824
# Test Accuracy: 0.5091693635382956
# Test ROC AUC: 0.5092190889370932
# ------------------------------------------------------------
# Iteration: 146
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5442764578833693
# Validation ROC AUC: 0.5446081908459643
# Test Accuracy: 0.5124056094929881
# Test ROC AUC: 0.512403061081992
# ------------------------------------------------------------
# Iteration: 147
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5399568034557235
# Validation ROC AUC: 0.5401609049503473
# Test Accuracy: 0.5275080906148867
# Test ROC AUC: 0.5274594322847328
# ------------------------------------------------------------
# Iteration: 148
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.5269978401727862
# Validation ROC AUC: 0.5276170387515866
# Test Accuracy: 0.5307443365695793
# Test ROC AUC: 0.5308412389561785
# ------------------------------------------------------------
# Iteration: 149
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5323974082073434
# Validation ROC AUC: 0.5325356529530352
# Test Accuracy: 0.5264293419633226
# Test ROC AUC: 0.5265261188124343
# ------------------------------------------------------------
# Iteration: 150
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5388768898488121
# Validation ROC AUC: 0.5389755842604346
# Test Accuracy: 0.5329018338727076
# Test ROC AUC: 0.5329173377524137
# ------------------------------------------------------------
# Iteration: 151
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5485961123110151
# Validation ROC AUC: 0.5490974762935863
# Test Accuracy: 0.5318230852211435
# Test ROC AUC: 0.531797827078659
# ------------------------------------------------------------
# Iteration: 152
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.531317494600432
# Validation ROC AUC: 0.5317703277831702
# Test Accuracy: 0.5134843581445523
# Test ROC AUC: 0.5134643851302916
# ------------------------------------------------------------
# Iteration: 153
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 10, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5345572354211663
# Validation ROC AUC: 0.5346542970208318
# Test Accuracy: 0.5285868392664509
# Test ROC AUC: 0.5284858443577594
# ------------------------------------------------------------
# Iteration: 154
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 5}
# Validation Accuracy: 0.521598272138229
# Validation ROC AUC: 0.5217324348540282
# Test Accuracy: 0.5372168284789643
# Test ROC AUC: 0.5372091832459759
# ------------------------------------------------------------
# Iteration: 155
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 10}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5436328679160757
# Test Accuracy: 0.5145631067961165
# Test ROC AUC: 0.5146071704542281
# ------------------------------------------------------------
# Iteration: 156
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 10, 'n_estimators': 20}
# Validation Accuracy: 0.5291576673866091
# Validation ROC AUC: 0.5293576868513402
# Test Accuracy: 0.5285868392664509
# Test ROC AUC: 0.5285905802835783
# ------------------------------------------------------------
# Iteration: 157
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 5}
# Validation Accuracy: 0.521598272138229
# Validation ROC AUC: 0.5217324348540282
# Test Accuracy: 0.5372168284789643
# Test ROC AUC: 0.5372091832459759
# ------------------------------------------------------------
# Iteration: 158
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 10}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5436328679160757
# Test Accuracy: 0.5145631067961165
# Test ROC AUC: 0.5146071704542281
# ------------------------------------------------------------
# Iteration: 159
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 25, 'n_estimators': 20}
# Validation Accuracy: 0.5291576673866091
# Validation ROC AUC: 0.5293576868513402
# Test Accuracy: 0.5285868392664509
# Test ROC AUC: 0.5285905802835783
# ------------------------------------------------------------
# Iteration: 160
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 5}
# Validation Accuracy: 0.5431965442764579
# Validation ROC AUC: 0.5435068692600613
# Test Accuracy: 0.5329018338727076
# Test ROC AUC: 0.5329522497276866
# ------------------------------------------------------------
# Iteration: 161
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 10}
# Validation Accuracy: 0.5485961123110151
# Validation ROC AUC: 0.5488034794295528
# Test Accuracy: 0.5221143473570659
# Test ROC AUC: 0.5221528120432349
# ------------------------------------------------------------
# Iteration: 162
# Params: {'bootstrap': False, 'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 50, 'n_estimators': 20}
# Validation Accuracy: 0.5399568034557235
# Validation ROC AUC: 0.5400769058463376
# Test Accuracy: 0.5339805825242718
# Test ROC AUC: 0.5339321125003491
# ------------------------------------------------------------
# Final Results:
#                                                 params  val_accuracy  \
# 0    {'bootstrap': True, 'max_depth': None, 'min_sa...      0.522678
# 1    {'bootstrap': True, 'max_depth': None, 'min_sa...      0.543197
# 2    {'bootstrap': True, 'max_depth': None, 'min_sa...      0.526998
# 3    {'bootstrap': True, 'max_depth': None, 'min_sa...      0.523758
# 4    {'bootstrap': True, 'max_depth': None, 'min_sa...      0.520518
# ..                                                 ...           ...
# 157  {'bootstrap': False, 'max_depth': 20, 'min_sam...      0.543197
# 158  {'bootstrap': False, 'max_depth': 20, 'min_sam...      0.529158
# 159  {'bootstrap': False, 'max_depth': 20, 'min_sam...      0.543197
# 160  {'bootstrap': False, 'max_depth': 20, 'min_sam...      0.548596
# 161  {'bootstrap': False, 'max_depth': 20, 'min_sam...      0.539957
#
#      val_roc_auc  test_accuracy  test_roc_auc
# 0       0.522918       0.521036      0.520975
# 1       0.543297       0.528587      0.528404
# 2       0.526777       0.532902      0.532789
# 3       0.523977       0.522114      0.522118
# 4       0.520841       0.521036      0.521080
# ..           ...            ...           ...
# 157     0.543633       0.514563      0.514607
# 158     0.529358       0.528587      0.528591
# 159     0.543507       0.532902      0.532952
# 160     0.548803       0.522114      0.522153
# 161     0.540077       0.533981      0.533932
#
# [162 rows x 5 columns]
