# %% [markdown]
# Retrying splitting, ensuring temporatility respected and included a hold-out set

# %%
import pandas as pd

# Load the data
file_path = 'trades(final).csv'
data = pd.read_csv(file_path)

# Ensure data is sorted by Entry_Date
data['Entry_Date'] = pd.to_datetime(data['Entry_Date'])  # Convert to datetime if not already
data = data.sort_values(by='Entry_Date')

# Define the sizes for train, hold-out, validation, and test sets
train_size = 0.75  # 75% of the original data for training
holdout_size = 0.05  # 5% of the original data for holdout
val_size = 0.10  # 10% of the original data for validation
test_size = 0.10  # 10% of the original data for testing

# Calculate the index boundaries for each split
n = len(data)
train_end = int(train_size * n)
holdout_end = int((train_size + holdout_size) * n)
val_end = int((train_size + holdout_size + val_size) * n)

# Split the data while maintaining temporal order
train_data = data.iloc[:train_end]
holdout_data = data.iloc[train_end:holdout_end]
val_data = data.iloc[holdout_end:val_end]
test_data = data.iloc[val_end:]

# Interpolating missing values
train_data = train_data.interpolate(method='linear', limit_direction='both')
val_data = val_data.interpolate(method='linear', limit_direction='both')
test_data = test_data.interpolate(method='linear', limit_direction='both')
holdout_data = holdout_data.interpolate(method='linear', limit_direction='both')

# Define features to be shifted
features_to_shift = [
    'Open', 'High', 'Low', 'Last', 'MACD_At_Entry', 'Day_Of_Week_At_Entry', 'ROC14_At_Entry',
    'SMA5_At_Entry', 'SMA7_At_Entry', 'SMA10_At_Entry', 'SMA15_At_Entry',
    'EMA5_At_Entry', 'EMA7_At_Entry', 'EMA10_At_Entry', 'EMA15_At_Entry',
    'RSI5_At_Entry', 'RSI10_At_Entry', 'RSI15_At_Entry',
    'ATR5_At_Entry', 'ATR15_At_Entry',
    'BB5_High_At_Entry', 'BB5_Low_At_Entry', 'BB5_MAvg_At_Entry',
    'BB10_High_At_Entry', 'BB10_Low_At_Entry', 'BB10_MAvg_At_Entry',
    'BB15_High_At_Entry', 'BB15_Low_At_Entry', 'BB15_MAvg_At_Entry',
    'Stoch5_K_At_Entry', 'Stoch5_D_At_Entry', 'Stoch7_K_At_Entry', 'Stoch7_D_At_Entry',
    'Stoch21_K_At_Entry', 'Stoch21_D_At_Entry'
]

# Shifting the features back by one period to prevent lookahead bias
train_data[features_to_shift] = train_data[features_to_shift].shift(1)
val_data[features_to_shift] = val_data[features_to_shift].shift(1)
test_data[features_to_shift] = test_data[features_to_shift].shift(1)
holdout_data[features_to_shift] = holdout_data[features_to_shift].shift(1)

# Drop rows with NaNs after shifting
train_data.dropna(inplace=True)
val_data.dropna(inplace=True)
test_data.dropna(inplace=True)
holdout_data.dropna(inplace=True)

# Save the splits into separate files
train_data.to_csv('train_data(new).csv', index=False)
val_data.to_csv('val_data(new).csv', index=False)
test_data.to_csv('test_data(new).csv', index=False)
holdout_data.to_csv('holdout_data(new).csv', index=False)

print("Data split, interpolated, shifted, and saved successfully.")
# Out:
# /var/folders/zw/9vch0yrs50jfl_28l8p1__m80000gn/T/ipykernel_28120/2402287112.py:30: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   train_data = train_data.interpolate(method='linear', limit_direction='both')
# /var/folders/zw/9vch0yrs50jfl_28l8p1__m80000gn/T/ipykernel_28120/2402287112.py:31: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   val_data = val_data.interpolate(method='linear', limit_direction='both')
# /var/folders/zw/9vch0yrs50jfl_28l8p1__m80000gn/T/ipykernel_28120/2402287112.py:32: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   test_data = test_data.interpolate(method='linear', limit_direction='both')
# /var/folders/zw/9vch0yrs50jfl_28l8p1__m80000gn/T/ipykernel_28120/2402287112.py:33: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   holdout_data = holdout_data.interpolate(method='linear', limit_direction='both')
# Data split, interpolated, shifted, and saved successfully.

# %% [markdown]
# Checking the original data.

# %%
import pandas as pd

# Load the dataset
file_path = 'trades(final).csv'
df = pd.read_csv(file_path)

# Group by Entry_Date to find instances where multiple strategies traded on the same day
grouped = df.groupby('Entry_Date')

# Initialize a list to store any discrepancies found
discrepancies = []

# Iterate over each group
for entry_date, group in grouped:
    if len(group) > 1:  # Only consider dates where more than one trade occurred
        # Drop the columns that are not supposed to match, like Trade_ID and Strategy
        comparison_columns = [col for col in df.columns if col not in ['Strategy', 'Trade_ID']]
        
        # Check if all rows in the group are identical
        for col in comparison_columns:
            if not group[col].nunique() == 1:
                discrepancies.append({
                    'Entry_Date': entry_date,
                    'Column': col,
                    'Unique Values': group[col].unique(),
                    'Rows': group[[col, 'Strategy', 'Trade_ID']].to_dict(orient='records')
                })

# Output the result
if discrepancies:
    print("Discrepancies found:")
    for discrepancy in discrepancies:
        print(f"\nEntry Date: {discrepancy['Entry_Date']}, Column: {discrepancy['Column']}, Unique Values: {discrepancy['Unique Values']}")
        print("Affected Rows:")
        for row in discrepancy['Rows']:
            print(row)
else:
    print("No discrepancies found. All columns match for trades on the same entry date.")
# Out:
# No discrepancies found. All columns match for trades on the same entry date.

# %% [markdown]
# Changin splitting to ensure that mutiple trades on the same day have the same feature values when shiting

# %%
import pandas as pd

# Load the data
file_path = 'trades(final).csv'
data = pd.read_csv(file_path)

# Ensure data is sorted by Entry_Date
data['Entry_Date'] = pd.to_datetime(data['Entry_Date'])  # Convert to datetime if not already
data = data.sort_values(by='Entry_Date')

# Define the sizes for train, hold-out, validation, and test sets
train_size = 0.75  # 75% of the original data for training
holdout_size = 0.05  # 5% of the original data for holdout
val_size = 0.10  # 10% of the original data for validation
test_size = 0.10  # 10% of the original data for testing

# Calculate the index boundaries for each split
n = len(data)
train_end = int(train_size * n)
holdout_end = int((train_size + holdout_size) * n)
val_end = int((train_size + holdout_size + val_size) * n)

# Split the data while maintaining temporal order
train_data = data.iloc[:train_end]
holdout_data = data.iloc[train_end:holdout_end]
val_data = data.iloc[holdout_end:val_end]
test_data = data.iloc[val_end:]

# Interpolating missing values
train_data = train_data.interpolate(method='linear', limit_direction='both')
val_data = val_data.interpolate(method='linear', limit_direction='both')
test_data = test_data.interpolate(method='linear', limit_direction='both')
holdout_data = holdout_data.interpolate(method='linear', limit_direction='both')

# Shift the target variable (e.g., Profit_Loss) up by one period
target_variable = 'Target'  # Change this to the actual target column name
train_data[target_variable] = train_data[target_variable].shift(-1)
val_data[target_variable] = val_data[target_variable].shift(-1)
test_data[target_variable] = test_data[target_variable].shift(-1)
holdout_data[target_variable] = holdout_data[target_variable].shift(-1)

# Drop rows with NaNs after shifting (these will be the last rows in each set)
train_data.dropna(inplace=True)
val_data.dropna(inplace=True)
test_data.dropna(inplace=True)
holdout_data.dropna(inplace=True)

# Save the splits into separate files
train_data.to_csv('train_data(new2).csv', index=False)
val_data.to_csv('val_data(new2).csv', index=False)
test_data.to_csv('test_data(new2).csv', index=False)
holdout_data.to_csv('holdout_data(new2).csv', index=False)

print("Data split, interpolated, target shifted, and saved successfully.")
# Out:
# /var/folders/zw/9vch0yrs50jfl_28l8p1__m80000gn/T/ipykernel_28120/902230378.py:30: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   train_data = train_data.interpolate(method='linear', limit_direction='both')
# /var/folders/zw/9vch0yrs50jfl_28l8p1__m80000gn/T/ipykernel_28120/902230378.py:31: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   val_data = val_data.interpolate(method='linear', limit_direction='both')
# /var/folders/zw/9vch0yrs50jfl_28l8p1__m80000gn/T/ipykernel_28120/902230378.py:32: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   test_data = test_data.interpolate(method='linear', limit_direction='both')
# /var/folders/zw/9vch0yrs50jfl_28l8p1__m80000gn/T/ipykernel_28120/902230378.py:33: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   holdout_data = holdout_data.interpolate(method='linear', limit_direction='both')
# Data split, interpolated, target shifted, and saved successfully.

# %%
import pandas as pd

# Load the dataset
file_path = 'train_data(new2).csv'
df = pd.read_csv(file_path)

# Group by Entry_Date to find instances where multiple strategies traded on the same day
grouped = df.groupby('Entry_Date')

# Initialize a list to store any discrepancies found
discrepancies = []

# Iterate over each group
for entry_date, group in grouped:
    if len(group) > 1:  # Only consider dates where more than one trade occurred
        # Drop the columns that are not supposed to match, like Trade_ID and Strategy
        comparison_columns = [col for col in df.columns if col not in ['Strategy', 'Trade_ID']]
        
        # Check if all rows in the group are identical
        for col in comparison_columns:
            if not group[col].nunique() == 1:
                discrepancies.append({
                    'Entry_Date': entry_date,
                    'Column': col,
                    'Unique Values': group[col].unique(),
                    'Rows': group[[col, 'Strategy', 'Trade_ID']].to_dict(orient='records')
                })

# Output the result
if discrepancies:
    print("Discrepancies found:")
    for discrepancy in discrepancies:
        print(f"\nEntry Date: {discrepancy['Entry_Date']}, Column: {discrepancy['Column']}, Unique Values: {discrepancy['Unique Values']}")
        print("Affected Rows:")
        for row in discrepancy['Rows']:
            print(row)
else:
    print("No discrepancies found. All columns match for trades on the same entry date.")
# Out:
# Discrepancies found:
#
# Entry Date: 1990-03-13, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T2'}
#
# Entry Date: 1990-03-21, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T10'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T11'}
#
# Entry Date: 1990-03-22, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T12'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T13'}
#
# Entry Date: 1990-04-02, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T21'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T22'}
#
# Entry Date: 1990-05-23, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T47'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T48'}
#
# Entry Date: 1990-06-01, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T56'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T57'}
#
# Entry Date: 1990-06-13, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T66'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T67'}
#
# Entry Date: 1990-08-09, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T93'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T94'}
#
# Entry Date: 1990-08-10, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T95'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T96'}
#
# Entry Date: 1990-09-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T104'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T105'}
#
# Entry Date: 1990-09-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T115'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T116'}
#
# Entry Date: 1990-10-29, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T138'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T139'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T140'}
#
# Entry Date: 1990-10-30, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T141'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T142'}
#
# Entry Date: 1990-11-26, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_1', 'Trade_ID': 'Strategy_1_T151'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T152'}
#
# Entry Date: 1990-12-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T157'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T158'}
#
# Entry Date: 1990-12-05, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T159'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T160'}
#
# Entry Date: 1990-12-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T161'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T162'}
#
# Entry Date: 1990-12-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T172'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T173'}
#
# Entry Date: 1991-01-11, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T186'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T187'}
#
# Entry Date: 1991-02-15, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T201'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T202'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T203'}
#
# Entry Date: 1991-03-01, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T216'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T217'}
#
# Entry Date: 1991-03-19, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T233'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T234'}
#
# Entry Date: 1991-03-25, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T239'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T240'}
#
# Entry Date: 1991-03-27, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T242'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T243'}
#
# Entry Date: 1991-04-17, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T255'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T256'}
#
# Entry Date: 1991-04-19, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T259'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T260'}
#
# Entry Date: 1991-05-06, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T273'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T274'}
#
# Entry Date: 1991-05-10, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T279'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T280'}
#
# Entry Date: 1991-05-20, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T285'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T286'}
#
# Entry Date: 1991-05-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T291'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T292'}
#
# Entry Date: 1991-06-13, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T308'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T309'}
#
# Entry Date: 1991-06-14, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T310'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T311'}
#
# Entry Date: 1991-07-02, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T327'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T328'}
#
# Entry Date: 1991-08-16, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T354'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T355'}
#
# Entry Date: 1991-08-23, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T360'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T361'}
#
# Entry Date: 1991-08-26, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T362'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T363'}
#
# Entry Date: 1991-08-28, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T365'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T366'}
#
# Entry Date: 1991-08-30, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T367'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T368'}
#
# Entry Date: 1991-10-16, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T390'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T391'}
#
# Entry Date: 1991-10-18, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T393'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T394'}
#
# Entry Date: 1991-10-21, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T395'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T396'}
#
# Entry Date: 1991-10-25, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T402'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T403'}
#
# Entry Date: 1991-11-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_1', 'Trade_ID': 'Strategy_1_T413'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T414'}
#
# Entry Date: 1991-12-02, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T425'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T426'}
#
# Entry Date: 1991-12-05, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T428'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T429'}
#
# Entry Date: 1992-01-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T440'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T441'}
#
# Entry Date: 1992-01-10, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T445'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T446'}
#
# Entry Date: 1992-01-21, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T455'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T456'}
#
# Entry Date: 1992-01-23, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T458'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T459'}
#
# Entry Date: 1992-02-19, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T482'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T483'}
#
# Entry Date: 1992-02-20, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T484'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T485'}
#
# Entry Date: 1992-02-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T487'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T488'}
#
# Entry Date: 1992-03-04, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T496'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T497'}
#
# Entry Date: 1992-03-05, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T498'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T499'}
#
# Entry Date: 1992-03-09, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T501'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T502'}
#
# Entry Date: 1992-03-10, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T503'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T504'}
#
# Entry Date: 1992-03-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T506'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T507'}
#
# Entry Date: 1992-03-18, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T512'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T513'}
#
# Entry Date: 1992-04-03, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T524'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T525'}
#
# Entry Date: 1992-04-16, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T532'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T533'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T534'}
#
# Entry Date: 1992-04-22, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T539'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T540'}
#
# Entry Date: 1992-07-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T585'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T586'}
#
# Entry Date: 1992-07-30, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T591'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T592'}
#
# Entry Date: 1992-08-04, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T596'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T597'}
#
# Entry Date: 1992-08-05, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T598'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T599'}
#
# Entry Date: 1992-08-14, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T609'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T610'}
#
# Entry Date: 1992-08-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T614'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T615'}
#
# Entry Date: 1992-08-27, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_1', 'Trade_ID': 'Strategy_1_T618'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T619'}
#
# Entry Date: 1992-09-10, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T624'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T625'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T626'}
#
# Entry Date: 1992-09-18, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T634'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T635'}
#
# Entry Date: 1992-10-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T652'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T653'}
#
# Entry Date: 1992-10-20, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T662'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T663'}
#
# Entry Date: 1992-10-26, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T668'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T669'}
#
# Entry Date: 1992-10-27, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T670'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T671'}
#
# Entry Date: 1992-11-03, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T677'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T678'}
#
# Entry Date: 1992-11-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T679'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T680'}
#
# Entry Date: 1992-11-06, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T682'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T683'}
#
# Entry Date: 1992-11-16, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T690'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T691'}
#
# Entry Date: 1992-11-23, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T696'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T697'}
#
# Entry Date: 1992-11-25, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T699'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T700'}
#
# Entry Date: 1992-11-27, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T702'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T703'}
#
# Entry Date: 1992-12-07, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T709'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T710'}
#
# Entry Date: 1992-12-11, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T713'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T714'}
#
# Entry Date: 1992-12-15, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T716'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T717'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T718'}
#
# Entry Date: 1992-12-21, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T722'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T723'}
#
# Entry Date: 1992-12-30, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T731'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T732'}
#
# Entry Date: 1993-01-05, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T737'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T738'}
#
# Entry Date: 1993-01-08, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T742'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T743'}
#
# Entry Date: 1993-01-11, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T744'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T745'}
#
# Entry Date: 1993-01-13, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T747'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T748'}
#
# Entry Date: 1993-01-21, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T756'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T757'}
#
# Entry Date: 1993-01-22, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T758'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T759'}
#
# Entry Date: 1993-02-03, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T768'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T769'}
#
# Entry Date: 1993-02-09, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T774'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T775'}
#
# Entry Date: 1993-02-15, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T781'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T782'}
#
# Entry Date: 1993-02-16, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T783'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T784'}
#
# Entry Date: 1993-03-01, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T800'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T801'}
#
# Entry Date: 1993-03-02, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T802'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T803'}
#
# Entry Date: 1993-03-11, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T811'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T812'}
#
# Entry Date: 1993-03-12, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T813'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T814'}
#
# Entry Date: 1993-03-16, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T816'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T817'}
#
# Entry Date: 1993-04-07, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T828'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T829'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T830'}
#
# Entry Date: 1993-05-10, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T846'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T847'}
#
# Entry Date: 1993-06-08, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T868'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T869'}
#
# Entry Date: 1993-06-10, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T871'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T872'}
#
# Entry Date: 1993-06-14, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T874'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T875'}
#
# Entry Date: 1993-06-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T889'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T890'}
#
# Entry Date: 1993-06-25, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T891'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T892'}
#
# Entry Date: 1993-06-29, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T894'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T895'}
#
# Entry Date: 1993-07-01, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T897'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T898'}
#
# Entry Date: 1993-07-02, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T899'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T900'}
#
# Entry Date: 1993-07-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T907'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T908'}
#
# Entry Date: 1993-07-28, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T919'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T920'}
#
# Entry Date: 1993-07-30, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T922'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T923'}
#
# Entry Date: 1993-08-02, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T924'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T925'}
#
# Entry Date: 1993-08-04, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T926'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T927'}
#
# Entry Date: 1993-08-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T935'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T936'}
#
# Entry Date: 1993-08-30, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T943'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T944'}
#
# Entry Date: 1993-08-31, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T945'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T946'}
#
# Entry Date: 1993-09-08, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T953'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T954'}
#
# Entry Date: 1993-09-09, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T955'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T956'}
#
# Entry Date: 1993-09-23, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T969'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T970'}
#
# Entry Date: 1993-09-30, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T975'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T976'}
#
# Entry Date: 1993-11-17, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1006'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1007'}
#
# Entry Date: 1993-11-18, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1008'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1009'}
#
# Entry Date: 1993-11-26, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1013'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1014'}
#
# Entry Date: 1993-12-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1021'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1022'}
#
# Entry Date: 1993-12-15, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1026'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1027'}
#
# Entry Date: 1993-12-30, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1038'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1039'}
#
# Entry Date: 1993-12-31, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1040'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1041'}
#
# Entry Date: 1994-01-07, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1047'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1048'}
#
# Entry Date: 1994-02-03, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1065'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1066'}
#
# Entry Date: 1994-02-07, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1068'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1069'}
#
# Entry Date: 1994-02-18, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1079'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1080'}
#
# Entry Date: 1994-02-23, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1084'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1085'}
#
# Entry Date: 1994-03-07, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1093'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1094'}
#
# Entry Date: 1994-03-28, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1102'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1103'}
#
# Entry Date: 1994-03-29, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1104'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1105'}
#
# Entry Date: 1994-03-31, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1106'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1107'}
#
# Entry Date: 1994-04-01, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1108'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1109'}
#
# Entry Date: 1994-04-07, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1115'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1116'}
#
# Entry Date: 1994-04-08, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1117'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1118'}
#
# Entry Date: 1994-04-15, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1124'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1125'}
#
# Entry Date: 1994-04-21, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1129'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1130'}
#
# Entry Date: 1994-05-05, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1137'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1138'}
#
# Entry Date: 1994-05-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1139'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1140'}
#
# Entry Date: 1994-05-09, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1141'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1142'}
#
# Entry Date: 1994-05-10, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1143'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1144'}
#
# Entry Date: 1994-05-12, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1146'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1147'}
#
# Entry Date: 1994-05-16, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1149'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1150'}
#
# Entry Date: 1994-05-17, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1151'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1152'}
#
# Entry Date: 1994-05-19, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1154'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1155'}
#
# Entry Date: 1994-06-17, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1166'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1167'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1168'}
#
# Entry Date: 1994-06-20, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1169'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1170'}
#
# Entry Date: 1994-06-29, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1175'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1176'}
#
# Entry Date: 1994-07-01, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1179'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1180'}
#
# Entry Date: 1994-07-15, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1192'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1193'}
#
# Entry Date: 1994-07-18, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1194'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1195'}
#
# Entry Date: 1994-07-20, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1197'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1198'}
#
# Entry Date: 1994-07-21, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1199'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1200'}
#
# Entry Date: 1994-08-30, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1215'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1216'}
#
# Entry Date: 1994-10-03, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1236'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1237'}
#
# Entry Date: 1994-10-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1238'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1239'}
#
# Entry Date: 1994-10-10, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1245'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1246'}
#
# Entry Date: 1994-10-11, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1247'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1248'}
#
# Entry Date: 1994-11-08, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1265'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1266'}
#
# Entry Date: 1994-11-23, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1285'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1286'}
#
# Entry Date: 1994-12-05, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1299'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1300'}
#
# Entry Date: 1994-12-16, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1315'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1316'}
#
# Entry Date: 1994-12-19, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1317'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1318'}
#
# Entry Date: 1995-01-09, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1332'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1333'}
#
# Entry Date: 1995-01-27, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1342'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1343'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1344'}
#
# Entry Date: 1995-01-30, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1345'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1346'}
#
# Entry Date: 1995-02-09, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1358'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1359'}
#
# Entry Date: 1995-02-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1373'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1374'}
#
# Entry Date: 1995-03-10, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1384'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1385'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1386'}
#
# Entry Date: 1995-03-13, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1387'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1388'}
#
# Entry Date: 1995-03-15, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1390'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1391'}
#
# Entry Date: 1995-03-21, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1395'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1396'}
#
# Entry Date: 1995-04-17, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1417'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1418'}
#
# Entry Date: 1995-04-18, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1419'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1420'}
#
# Entry Date: 1995-04-26, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1428'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1429'}
#
# Entry Date: 1995-04-27, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1430'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1431'}
#
# Entry Date: 1995-05-04, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1439'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1440'}
#
# Entry Date: 1995-05-05, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1441'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1442'}
#
# Entry Date: 1995-05-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1450'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1451'}
#
# Entry Date: 1995-05-15, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1452'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1453'}
#
# Entry Date: 1995-05-18, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1457'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1458'}
#
# Entry Date: 1995-05-19, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1459'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1460'}
#
# Entry Date: 1995-05-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1464'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1465'}
#
# Entry Date: 1995-06-01, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1471'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1472'}
#
# Entry Date: 1995-06-02, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1473'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1474'}
#
# Entry Date: 1995-07-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1498'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1499'}
#
# Entry Date: 1995-07-13, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1500'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1501'}
#
# Entry Date: 1995-07-24, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1508'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1509'}
#
# Entry Date: 1995-08-14, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1517'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1518'}
#
# Entry Date: 1995-08-15, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1519'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1520'}
#
# Entry Date: 1995-09-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1537'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1538'}
#
# Entry Date: 1995-09-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1540'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1541'}
#
# Entry Date: 1995-09-15, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1550'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1551'}
#
# Entry Date: 1995-09-18, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1552'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1553'}
#
# Entry Date: 1995-10-03, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1560'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1561'}
#
# Entry Date: 1995-10-13, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1569'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1570'}
#
# Entry Date: 1995-10-31, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1578'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1579'}
#
# Entry Date: 1995-11-02, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1581'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T1582'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1583'}
#
# Entry Date: 1995-11-27, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1605'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1606'}
#
# Entry Date: 1995-11-28, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1607'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1608'}
#
# Entry Date: 1995-11-30, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1610'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1611'}
#
# Entry Date: 1995-12-07, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T1617'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T1618'}
#
# Entry Date: 1995-12-29, Column: Target, Unique Values: [1. 0.]
# ...
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6548'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6549'}
#
# Entry Date: 2013-06-03, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6550'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6551'}
#
# Entry Date: 2013-06-05, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6553'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6554'}
#
# Entry Date: 2013-06-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6555'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6556'}
#
# Entry Date: 2013-06-10, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6558'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6559'}
#
# Entry Date: 2013-06-11, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6560'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6561'}
#
# Entry Date: 2013-06-13, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6563'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6564'}
#
# Entry Date: 2013-06-20, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6571'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T6572'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6573'}
#
# Entry Date: 2013-06-26, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6578'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6579'}
#
# Entry Date: 2013-06-27, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6580'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6581'}
#
# Entry Date: 2013-08-01, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6597'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T6598'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6599'}
#
# Entry Date: 2013-08-07, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6604'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6605'}
#
# Entry Date: 2013-08-13, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6609'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6610'}
#
# Entry Date: 2013-08-14, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6611'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6612'}
#
# Entry Date: 2013-08-19, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6616'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6617'}
#
# Entry Date: 2013-08-20, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6618'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6619'}
#
# Entry Date: 2013-08-27, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6625'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6626'}
#
# Entry Date: 2013-08-28, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6627'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6628'}
#
# Entry Date: 2013-08-30, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6630'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6631'}
#
# Entry Date: 2013-09-03, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6633'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6634'}
#
# Entry Date: 2013-09-27, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6649'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6650'}
#
# Entry Date: 2013-09-30, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6651'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6652'}
#
# Entry Date: 2013-10-02, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6654'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6655'}
#
# Entry Date: 2013-10-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6657'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6658'}
#
# Entry Date: 2013-11-01, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6675'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6676'}
#
# Entry Date: 2013-11-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6677'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6678'}
#
# Entry Date: 2013-11-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6688'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6689'}
#
# Entry Date: 2013-11-28, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6697'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6698'}
#
# Entry Date: 2013-12-05, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6704'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6705'}
#
# Entry Date: 2013-12-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6706'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6707'}
#
# Entry Date: 2013-12-10, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6709'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6710'}
#
# Entry Date: 2013-12-12, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6712'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6713'}
#
# Entry Date: 2013-12-13, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6714'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6715'}
#
# Entry Date: 2013-12-19, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6718'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6719'}
#
# Entry Date: 2013-12-20, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6720'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6721'}
#
# Entry Date: 2013-12-27, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6724'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T6725'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6726'}
#
# Entry Date: 2013-12-30, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6727'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6728'}
#
# Entry Date: 2014-01-03, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6734'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6735'}
#
# Entry Date: 2014-01-09, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6740'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6741'}
#
# Entry Date: 2014-01-10, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6742'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6743'}
#
# Entry Date: 2014-01-16, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6749'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6750'}
#
# Entry Date: 2014-01-17, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6751'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6752'}
#
# Entry Date: 2014-01-21, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6754'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6755'}
#
# Entry Date: 2014-01-27, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6761'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6762'}
#
# Entry Date: 2014-01-28, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6763'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6764'}
#
# Entry Date: 2014-02-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6770'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6771'}
#
# Entry Date: 2014-02-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6773'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6774'}
#
# Entry Date: 2014-03-04, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6783'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6784'}
#
# Entry Date: 2014-03-12, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6787'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6788'}
#
# Entry Date: 2014-03-13, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6789'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T6790'}
#
# Entry Date: 2014-03-18, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6793'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6794'}
#
# Entry Date: 2014-03-21, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6797'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6798'}
#
# Entry Date: 2014-04-16, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6809'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6810'}
#
# Entry Date: 2014-04-17, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6811'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6812'}
#
# Entry Date: 2014-04-25, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6820'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6821'}
#
# Entry Date: 2014-05-21, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6831'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6832'}
#
# Entry Date: 2014-05-28, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6834'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T6835'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6836'}
#
# Entry Date: 2014-05-29, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6837'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6838'}
#
# Entry Date: 2014-06-04, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6844'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6845'}
#
# Entry Date: 2014-06-11, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6852'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6853'}
#
# Entry Date: 2014-06-12, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6854'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6855'}
#
# Entry Date: 2014-06-17, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6859'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6860'}
#
# Entry Date: 2014-07-03, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6869'}
# {'Target': 0.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T6870'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6871'}
#
# Entry Date: 2014-07-07, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6873'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6874'}
#
# Entry Date: 2014-07-11, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6878'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6879'}
#
# Entry Date: 2014-07-31, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6892'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6893'}
#
# Entry Date: 2014-08-06, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6899'}
# {'Target': 1.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6900'}
#
# Entry Date: 2014-08-22, Column: Target, Unique Values: [0. 1.]
# Affected Rows:
# {'Target': 0.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6909'}
# {'Target': 1.0, 'Strategy': 'Strategy_3', 'Trade_ID': 'Strategy_3_T6910'}
#
# Entry Date: 2014-09-02, Column: Target, Unique Values: [1. 0.]
# Affected Rows:
# {'Target': 1.0, 'Strategy': 'Strategy_2', 'Trade_ID': 'Strategy_2_T6919'}
# {'Target': 0.0, 'Strategy': 'Strategy_4', 'Trade_ID': 'Strategy_4_T6920'}
