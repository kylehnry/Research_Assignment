# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score
import json

# Load the dataset containing the feature combinations
combinations_file_path = 'feature_combination_results_retest.csv'
combinations_data = pd.read_csv(combinations_file_path)

# Filter the dataset for combinations with accuracy greater than 53%
filtered_combinations = combinations_data[combinations_data['Accuracy'] > 0.53]

# Load the train, validation, and test datasets
train_data = pd.read_csv('train_data.csv')
val_data = pd.read_csv('val_data.csv')
test_data = pd.read_csv('test_data.csv')

# Ensure the data is sorted by the 'Entry_Date' column
train_data['Entry_Date'] = pd.to_datetime(train_data['Entry_Date'])
val_data['Entry_Date'] = pd.to_datetime(val_data['Entry_Date'])
test_data['Entry_Date'] = pd.to_datetime(test_data['Entry_Date'])

train_data = train_data.sort_values(by='Entry_Date')
val_data = val_data.sort_values(by='Entry_Date')
test_data = test_data.sort_values(by='Entry_Date')

# Prepare to store results
results = []

# Loop over each feature combination
for index, row in filtered_combinations.iterrows():
    feature_list_str = row['Features']
    selected_features = json.loads(feature_list_str.replace("'", "\""))
    
    # Separating features and target variable
    X_train = train_data[selected_features]
    y_train = train_data['Target']
    X_val = val_data[selected_features]
    y_val = val_data['Target']
    X_test = test_data[selected_features]
    y_test = test_data['Target']

    # Initialize the Random Forest Classifier
    rf_clf = RandomForestClassifier(
        n_estimators=100,
        max_depth=None,
        min_samples_split=25,
        min_samples_leaf=5,
        bootstrap=True,
        random_state=42
    )

    # Fit the model to the training data
    rf_clf.fit(X_train, y_train)

    # Predict on the validation set
    y_val_pred = rf_clf.predict(X_val)

    # Calculate evaluation metrics for the validation set
    val_report = classification_report(y_val, y_val_pred, output_dict=True)
    roc_auc_val = roc_auc_score(y_val, y_val_pred)

    # Predict on the test set
    y_test_pred = rf_clf.predict(X_test)

    # Calculate evaluation metrics for the test set
    test_report = classification_report(y_test, y_test_pred, output_dict=True)
    roc_auc_test = roc_auc_score(y_test, y_test_pred)

    # Store the results
    results.append({
        'Features': feature_list_str,
        'Validation Report': val_report,
        'Validation ROC AUC': roc_auc_val,
        'Test Report': test_report,
        'Test ROC AUC': roc_auc_test
    })

    # Print progress update
    print(f"Completed {index + 1}/{len(filtered_combinations)} tests.")

    # Save results every 10 tests
    if (index + 1) % 10 == 0:
        partial_results_df = pd.DataFrame(results)
        partial_results_df.to_csv('partial_feature_combination_results.csv', index=False)
        print(f"Saved progress at {index + 1} tests.")

# Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Save final results to a CSV file
results_df.to_csv('feature_combination_results.csv', index=False)

print("Final results have been saved to 'feature_combination_results.csv'")
# Out:
# Completed 8/915 tests.
# Completed 17/915 tests.
# Completed 27/915 tests.
# Completed 33/915 tests.
# Completed 38/915 tests.
# Completed 50/915 tests.
# Saved progress at 50 tests.
# Completed 51/915 tests.
# Completed 52/915 tests.
# Completed 53/915 tests.
# Completed 59/915 tests.
# Completed 62/915 tests.
# Completed 74/915 tests.
# Completed 91/915 tests.
# Completed 98/915 tests.
# Completed 104/915 tests.
# Completed 107/915 tests.
# Completed 119/915 tests.
# Completed 127/915 tests.
# Completed 136/915 tests.
# Completed 137/915 tests.
# Completed 138/915 tests.
# Completed 140/915 tests.
# Saved progress at 140 tests.
# Completed 151/915 tests.
# Completed 152/915 tests.
# Completed 153/915 tests.
# Completed 154/915 tests.
# Completed 155/915 tests.
# Completed 156/915 tests.
# Completed 163/915 tests.
# Completed 168/915 tests.
# Completed 181/915 tests.
# Completed 182/915 tests.
# Completed 187/915 tests.
# Completed 188/915 tests.
# Completed 200/915 tests.
# Saved progress at 200 tests.
# Completed 206/915 tests.
# Completed 228/915 tests.
# Completed 233/915 tests.
# Completed 235/915 tests.
# Completed 238/915 tests.
# Completed 240/915 tests.
# Saved progress at 240 tests.
# Completed 272/915 tests.
# Completed 273/915 tests.
# Completed 275/915 tests.
# Completed 277/915 tests.
# Completed 280/915 tests.
# Saved progress at 280 tests.
# Completed 286/915 tests.
# Completed 287/915 tests.
# Completed 291/915 tests.
# Completed 299/915 tests.
# Completed 300/915 tests.
# Saved progress at 300 tests.
# Completed 318/915 tests.
# Completed 319/915 tests.
# Completed 322/915 tests.
# Completed 329/915 tests.
# Completed 330/915 tests.
# Saved progress at 330 tests.
# Completed 335/915 tests.
# Completed 338/915 tests.
# Completed 341/915 tests.
# Completed 350/915 tests.
# Saved progress at 350 tests.
# Completed 361/915 tests.
# Completed 362/915 tests.
# Completed 367/915 tests.
# Completed 379/915 tests.
# Completed 406/915 tests.
# Completed 407/915 tests.
# Completed 410/915 tests.
# Saved progress at 410 tests.
# Completed 411/915 tests.
# Completed 416/915 tests.
# Completed 421/915 tests.
# Completed 423/915 tests.
# Completed 424/915 tests.
# Completed 426/915 tests.
# Completed 428/915 tests.
# Completed 435/915 tests.
# Completed 437/915 tests.
# Completed 438/915 tests.
# Completed 451/915 tests.
# Completed 452/915 tests.
# Completed 453/915 tests.
# Completed 456/915 tests.
# Completed 467/915 tests.
# Completed 468/915 tests.
# Completed 477/915 tests.
# Completed 480/915 tests.
# Saved progress at 480 tests.
# Completed 496/915 tests.
# Completed 498/915 tests.
# Completed 503/915 tests.
# Completed 505/915 tests.
# Completed 508/915 tests.
# Completed 510/915 tests.
# Saved progress at 510 tests.
# Completed 515/915 tests.
# Completed 543/915 tests.
# Completed 548/915 tests.
# Completed 556/915 tests.
# Completed 557/915 tests.
# Completed 558/915 tests.
# Completed 559/915 tests.
# Completed 561/915 tests.
# Completed 563/915 tests.
# Completed 565/915 tests.
# Completed 570/915 tests.
# Saved progress at 570 tests.
# Completed 576/915 tests.
# Completed 588/915 tests.
# Completed 591/915 tests.
# Completed 592/915 tests.
# Completed 600/915 tests.
# Saved progress at 600 tests.
# Completed 602/915 tests.
# Completed 603/915 tests.
# Completed 610/915 tests.
# Saved progress at 610 tests.
# Completed 615/915 tests.
# Completed 620/915 tests.
# Saved progress at 620 tests.
# Completed 631/915 tests.
# Completed 635/915 tests.
# Completed 637/915 tests.
# Completed 643/915 tests.
# Completed 647/915 tests.
# Completed 648/915 tests.
# Completed 651/915 tests.
# Completed 657/915 tests.
# Completed 658/915 tests.
# Completed 670/915 tests.
# Saved progress at 670 tests.
# Completed 677/915 tests.
# Completed 680/915 tests.
# Saved progress at 680 tests.
# Completed 681/915 tests.
# Completed 682/915 tests.
# Completed 691/915 tests.
# Completed 692/915 tests.
# Completed 693/915 tests.
# Completed 700/915 tests.
# Saved progress at 700 tests.
# Completed 704/915 tests.
# Completed 721/915 tests.
# Completed 724/915 tests.
# Completed 727/915 tests.
# Completed 735/915 tests.
# Completed 736/915 tests.
# Completed 737/915 tests.
# Completed 766/915 tests.
# Completed 770/915 tests.
# Saved progress at 770 tests.
# Completed 772/915 tests.
# Completed 775/915 tests.
# Completed 776/915 tests.
# Completed 778/915 tests.
# Completed 782/915 tests.
# Completed 791/915 tests.
# Completed 795/915 tests.
# Completed 803/915 tests.
# Completed 811/915 tests.
# Completed 812/915 tests.
# Completed 813/915 tests.
# Completed 815/915 tests.
# Completed 816/915 tests.
# Completed 818/915 tests.
# Completed 825/915 tests.
# Completed 826/915 tests.
# Completed 827/915 tests.
# Completed 828/915 tests.
# Completed 833/915 tests.
# Completed 839/915 tests.
# Completed 847/915 tests.
# Completed 856/915 tests.
# Completed 861/915 tests.
# Completed 862/915 tests.
# Completed 869/915 tests.
# Completed 872/915 tests.
# Completed 885/915 tests.
# Completed 902/915 tests.
# Completed 904/915 tests.
# Completed 906/915 tests.
# Completed 915/915 tests.
# Completed 916/915 tests.
# Completed 917/915 tests.
# Completed 919/915 tests.
# Completed 921/915 tests.
# Completed 927/915 tests.
# Completed 929/915 tests.
# Completed 947/915 tests.
# Completed 952/915 tests.
# Completed 953/915 tests.
# Completed 954/915 tests.
# Completed 956/915 tests.
# Completed 962/915 tests.
# Completed 966/915 tests.
# Completed 977/915 tests.
# Completed 978/915 tests.
# Completed 985/915 tests.
# Completed 992/915 tests.
# Completed 995/915 tests.
# Completed 996/915 tests.
# Completed 997/915 tests.
# Completed 1008/915 tests.
# Completed 1009/915 tests.
# Completed 1011/915 tests.
# Completed 1018/915 tests.
# Completed 1037/915 tests.
# Completed 1042/915 tests.
# Completed 1045/915 tests.
# Completed 1046/915 tests.
# Completed 1052/915 tests.
# Completed 1054/915 tests.
# Completed 1061/915 tests.
# Completed 1081/915 tests.
# Completed 1082/915 tests.
# Completed 1084/915 tests.
# Completed 1085/915 tests.
# Completed 1086/915 tests.
# Completed 1088/915 tests.
# Completed 1096/915 tests.
# Completed 1098/915 tests.
# Completed 1101/915 tests.
# Completed 1109/915 tests.
# Completed 1110/915 tests.
# Saved progress at 1110 tests.
# Completed 1113/915 tests.
# Completed 1120/915 tests.
# Saved progress at 1120 tests.
# Completed 1131/915 tests.
# Completed 1132/915 tests.
# Completed 1141/915 tests.
# Completed 1153/915 tests.
# Completed 1154/915 tests.
# Completed 1171/915 tests.
# Completed 1172/915 tests.
# Completed 1174/915 tests.
# Completed 1177/915 tests.
# Completed 1180/915 tests.
# Saved progress at 1180 tests.
# Completed 1187/915 tests.
# Completed 1217/915 tests.
# Completed 1219/915 tests.
# Completed 1224/915 tests.
# Completed 1225/915 tests.
# Completed 1227/915 tests.
# Completed 1228/915 tests.
# Completed 1231/915 tests.
# Completed 1232/915 tests.
# Completed 1234/915 tests.
# Completed 1238/915 tests.
# Completed 1242/915 tests.
# Completed 1246/915 tests.
# Completed 1248/915 tests.
# Completed 1261/915 tests.
# Completed 1262/915 tests.
# Completed 1263/915 tests.
# Completed 1267/915 tests.
# Completed 1278/915 tests.
# Completed 1287/915 tests.
# Completed 1290/915 tests.
# Saved progress at 1290 tests.
# Completed 1294/915 tests.
# Completed 1298/915 tests.
# Completed 1306/915 tests.
# Completed 1307/915 tests.
# Completed 1312/915 tests.
# Completed 1313/915 tests.
# Completed 1315/915 tests.
# Completed 1321/915 tests.
# Completed 1324/915 tests.
# Completed 1354/915 tests.
# Completed 1358/915 tests.
# Completed 1368/915 tests.
# Completed 1369/915 tests.
# Completed 1371/915 tests.
# Completed 1377/915 tests.
# Completed 1380/915 tests.
# Saved progress at 1380 tests.
# Completed 1396/915 tests.
# Completed 1399/915 tests.
# Completed 1400/915 tests.
# Saved progress at 1400 tests.
# Completed 1401/915 tests.
# Completed 1402/915 tests.
# Completed 1410/915 tests.
# Saved progress at 1410 tests.
# Completed 1415/915 tests.
# Completed 1422/915 tests.
# Completed 1442/915 tests.
# Completed 1444/915 tests.
# Completed 1445/915 tests.
# Completed 1447/915 tests.
# Completed 1449/915 tests.
# Completed 1456/915 tests.
# Completed 1470/915 tests.
# Saved progress at 1470 tests.
# Completed 1481/915 tests.
# Completed 1486/915 tests.
# Completed 1487/915 tests.
# Completed 1489/915 tests.
# Completed 1493/915 tests.
# Completed 1499/915 tests.
# Completed 1502/915 tests.
# Completed 1505/915 tests.
# Completed 1506/915 tests.
# Completed 1514/915 tests.
# Completed 1526/915 tests.
# Completed 1531/915 tests.
# Completed 1534/915 tests.
# Completed 1536/915 tests.
# Completed 1537/915 tests.
# Completed 1543/915 tests.
# Completed 1547/915 tests.
# Completed 1550/915 tests.
# Saved progress at 1550 tests.
# Completed 1558/915 tests.
# Completed 1576/915 tests.
# Completed 1577/915 tests.
# Completed 1580/915 tests.
# Saved progress at 1580 tests.
# Completed 1583/915 tests.
# Completed 1584/915 tests.
# Completed 1585/915 tests.
# Completed 1592/915 tests.
# Completed 1613/915 tests.
# Completed 1622/915 tests.
# Completed 1624/915 tests.
# Completed 1625/915 tests.
# Completed 1628/915 tests.
# Completed 1636/915 tests.
# Completed 1638/915 tests.
# Completed 1649/915 tests.
# Completed 1666/915 tests.
# Completed 1667/915 tests.
# Completed 1668/915 tests.
# Completed 1672/915 tests.
# Completed 1674/915 tests.
# Completed 1676/915 tests.
# Completed 1680/915 tests.
# Saved progress at 1680 tests.
# Completed 1681/915 tests.
# Completed 1685/915 tests.
# Completed 1686/915 tests.
# Completed 1712/915 tests.
# Completed 1717/915 tests.
# Completed 1718/915 tests.
# Completed 1720/915 tests.
# Saved progress at 1720 tests.
# Completed 1721/915 tests.
# Completed 1725/915 tests.
# Completed 1731/915 tests.
# Completed 1760/915 tests.
# Saved progress at 1760 tests.
# Completed 1761/915 tests.
# Completed 1763/915 tests.
# Completed 1765/915 tests.
# Completed 1766/915 tests.
# Completed 1771/915 tests.
# Completed 1776/915 tests.
# Completed 1778/915 tests.
# Completed 1782/915 tests.
# Completed 1783/915 tests.
# Completed 1784/915 tests.
# Completed 1793/915 tests.
# Completed 1802/915 tests.
# Completed 1803/915 tests.
# Completed 1808/915 tests.
# Completed 1811/915 tests.
# Completed 1821/915 tests.
# Completed 1823/915 tests.
# Completed 1826/915 tests.
# Completed 1827/915 tests.
# Completed 1847/915 tests.
# Completed 1849/915 tests.
# Completed 1856/915 tests.
# Completed 1859/915 tests.
# Completed 1866/915 tests.
# Completed 1868/915 tests.
# Completed 1875/915 tests.
# Completed 1881/915 tests.
# Completed 1891/915 tests.
# Completed 1895/915 tests.
# Completed 1898/915 tests.
# Completed 1899/915 tests.
# Completed 1900/915 tests.
# Saved progress at 1900 tests.
# Completed 1907/915 tests.
# Completed 1911/915 tests.
# Completed 1920/915 tests.
# Saved progress at 1920 tests.
# Completed 1921/915 tests.
# Completed 1922/915 tests.
# Completed 1924/915 tests.
# Completed 1943/915 tests.
# Completed 1952/915 tests.
# Completed 1961/915 tests.
# Completed 1976/915 tests.
# Completed 1982/915 tests.
# Completed 1983/915 tests.
# Completed 1989/915 tests.
# Completed 2012/915 tests.
# Completed 2015/915 tests.
# Completed 2026/915 tests.
# Completed 2030/915 tests.
# Saved progress at 2030 tests.
# Completed 2031/915 tests.
# Completed 2032/915 tests.
# Completed 2033/915 tests.
# Completed 2043/915 tests.
# Completed 2044/915 tests.
# Completed 2047/915 tests.
# Completed 2048/915 tests.
# Completed 2052/915 tests.
# Completed 2054/915 tests.
# Completed 2056/915 tests.
# Completed 2058/915 tests.
# Completed 2061/915 tests.
# Completed 2066/915 tests.
# Completed 2071/915 tests.
# Completed 2073/915 tests.
# Completed 2078/915 tests.
# Completed 2086/915 tests.
# Completed 2111/915 tests.
# Completed 2115/915 tests.
# Completed 2117/915 tests.
# Completed 2119/915 tests.
# Completed 2122/915 tests.
# Completed 2124/915 tests.
# Completed 2125/915 tests.
# Completed 2131/915 tests.
# Completed 2132/915 tests.
# Completed 2134/915 tests.
# Completed 2136/915 tests.
# Completed 2144/915 tests.
# Completed 2161/915 tests.
# Completed 2163/915 tests.
# Completed 2164/915 tests.
# Completed 2166/915 tests.
# Completed 2168/915 tests.
# Completed 2169/915 tests.
# Completed 2176/915 tests.
# Completed 2179/915 tests.
# Completed 2181/915 tests.
# Completed 2187/915 tests.
# Completed 2189/915 tests.
# Completed 2190/915 tests.
# Saved progress at 2190 tests.
# Completed 2191/915 tests.
# Completed 2192/915 tests.
# Completed 2193/915 tests.
# Completed 2198/915 tests.
# Completed 2200/915 tests.
# Saved progress at 2200 tests.
# Completed 2207/915 tests.
# Completed 2219/915 tests.
# Completed 2223/915 tests.
# Completed 2225/915 tests.
# Completed 2247/915 tests.
# Completed 2252/915 tests.
# Completed 2273/915 tests.
# Completed 2274/915 tests.
# Completed 2279/915 tests.
# Completed 2280/915 tests.
# Saved progress at 2280 tests.
# Completed 2282/915 tests.
# Completed 2296/915 tests.
# Completed 2298/915 tests.
# Completed 2302/915 tests.
# Completed 2306/915 tests.
# Completed 2309/915 tests.
# Completed 2311/915 tests.
# Completed 2314/915 tests.
# Completed 2315/915 tests.
# Completed 2316/915 tests.
# Completed 2318/915 tests.
# Completed 2324/915 tests.
# Completed 2326/915 tests.
# Completed 2328/915 tests.
# Completed 2331/915 tests.
# Completed 2342/915 tests.
# Completed 2350/915 tests.
# Saved progress at 2350 tests.
# Completed 2354/915 tests.
# Completed 2359/915 tests.
# Completed 2361/915 tests.
# Completed 2387/915 tests.
# Completed 2389/915 tests.
# Completed 2395/915 tests.
# Completed 2399/915 tests.
# Completed 2401/915 tests.
# Completed 2404/915 tests.
# Completed 2408/915 tests.
# Completed 2423/915 tests.
# Completed 2431/915 tests.
# Completed 2432/915 tests.
# Completed 2436/915 tests.
# Completed 2438/915 tests.
# Completed 2444/915 tests.
# Completed 2448/915 tests.
# Completed 2450/915 tests.
# Saved progress at 2450 tests.
# Completed 2460/915 tests.
# Saved progress at 2460 tests.
# Completed 2476/915 tests.
# Completed 2505/915 tests.
# Completed 2527/915 tests.
# Completed 2529/915 tests.
# Completed 2536/915 tests.
# Completed 2537/915 tests.
# Completed 2538/915 tests.
# Completed 2543/915 tests.
# Completed 2548/915 tests.
# Completed 2557/915 tests.
# Completed 2567/915 tests.
# Completed 2570/915 tests.
# Saved progress at 2570 tests.
# Completed 2573/915 tests.
# Completed 2583/915 tests.
# Completed 2585/915 tests.
# Completed 2586/915 tests.
# Completed 2591/915 tests.
# Completed 2594/915 tests.
# Completed 2606/915 tests.
# Completed 2611/915 tests.
# Completed 2613/915 tests.
# Completed 2617/915 tests.
# Completed 2628/915 tests.
# Completed 2630/915 tests.
# Saved progress at 2630 tests.
# Completed 2633/915 tests.
# Completed 2652/915 tests.
# Completed 2655/915 tests.
# Completed 2658/915 tests.
# Completed 2702/915 tests.
# Completed 2703/915 tests.
# Completed 2704/915 tests.
# Completed 2705/915 tests.
# Completed 2706/915 tests.
# Completed 2708/915 tests.
# Completed 2711/915 tests.
# Completed 2720/915 tests.
# Saved progress at 2720 tests.
# Completed 2721/915 tests.
# Completed 2726/915 tests.
# Completed 2727/915 tests.
# Completed 2729/915 tests.
# Completed 2730/915 tests.
# Saved progress at 2730 tests.
# Completed 2733/915 tests.
# Completed 2734/915 tests.
# Completed 2740/915 tests.
# Saved progress at 2740 tests.
# Completed 2746/915 tests.
# Completed 2749/915 tests.
# Completed 2772/915 tests.
# Completed 2774/915 tests.
# Completed 2792/915 tests.
# Completed 2797/915 tests.
# Completed 2798/915 tests.
# Completed 2802/915 tests.
# Completed 2808/915 tests.
# Completed 2809/915 tests.
# Completed 2820/915 tests.
# Saved progress at 2820 tests.
# Completed 2837/915 tests.
# Completed 2838/915 tests.
# Completed 2839/915 tests.
# Completed 2843/915 tests.
# Completed 2846/915 tests.
# Completed 2865/915 tests.
# Completed 2871/915 tests.
# Completed 2878/915 tests.
# Completed 2881/915 tests.
# Completed 2883/915 tests.
# Completed 2886/915 tests.
# Completed 2887/915 tests.
# Completed 2889/915 tests.
# Completed 2895/915 tests.
# Completed 2901/915 tests.
# Completed 2910/915 tests.
# Saved progress at 2910 tests.
# Completed 2913/915 tests.
# Completed 2925/915 tests.
# Completed 2932/915 tests.
# Completed 2933/915 tests.
# Completed 2940/915 tests.
# Saved progress at 2940 tests.
# Completed 2941/915 tests.
# Completed 2965/915 tests.
# Completed 2978/915 tests.
# Completed 2979/915 tests.
# Completed 2981/915 tests.
# Completed 2985/915 tests.
# Completed 2986/915 tests.
# Completed 2988/915 tests.
# Completed 2989/915 tests.
# Completed 2991/915 tests.
# Completed 2993/915 tests.
# Completed 2997/915 tests.
# Completed 3000/915 tests.
# Saved progress at 3000 tests.
# Completed 3007/915 tests.
# Completed 3016/915 tests.
# Completed 3022/915 tests.
# Completed 3023/915 tests.
# Completed 3028/915 tests.
# Completed 3032/915 tests.
# Completed 3045/915 tests.
# Completed 3053/915 tests.
# Completed 3065/915 tests.
# Completed 3068/915 tests.
# Completed 3071/915 tests.
# Completed 3074/915 tests.
# Completed 3106/915 tests.
# Completed 3109/915 tests.
# Completed 3113/915 tests.
# Completed 3114/915 tests.
# Completed 3116/915 tests.
# Completed 3121/915 tests.
# Completed 3122/915 tests.
# Completed 3126/915 tests.
# Completed 3129/915 tests.
# Completed 3133/915 tests.
# Completed 3134/915 tests.
# Completed 3135/915 tests.
# Completed 3143/915 tests.
# Completed 3155/915 tests.
# Completed 3157/915 tests.
# Completed 3168/915 tests.
# Completed 3171/915 tests.
# Completed 3175/915 tests.
# Completed 3180/915 tests.
# Saved progress at 3180 tests.
# Completed 3196/915 tests.
# Completed 3204/915 tests.
# Completed 3212/915 tests.
# Completed 3219/915 tests.
# Completed 3236/915 tests.
# Completed 3241/915 tests.
# Completed 3248/915 tests.
# Completed 3249/915 tests.
# Completed 3251/915 tests.
# Completed 3254/915 tests.
# Completed 3257/915 tests.
# Completed 3260/915 tests.
# Saved progress at 3260 tests.
# Completed 3261/915 tests.
# Completed 3268/915 tests.
# Completed 3270/915 tests.
# Saved progress at 3270 tests.
# Completed 3286/915 tests.
# Completed 3288/915 tests.
# Completed 3294/915 tests.
# Completed 3303/915 tests.
# Completed 3306/915 tests.
# Completed 3315/915 tests.
# Completed 3322/915 tests.
# Completed 3332/915 tests.
# Completed 3337/915 tests.
# Completed 3353/915 tests.
# Completed 3359/915 tests.
# Completed 3364/915 tests.
# Completed 3368/915 tests.
# Completed 3376/915 tests.
# Completed 3382/915 tests.
# Completed 3385/915 tests.
# Completed 3395/915 tests.
# Completed 3396/915 tests.
# Completed 3403/915 tests.
# Completed 3404/915 tests.
# Completed 3406/915 tests.
# Completed 3421/915 tests.
# Completed 3425/915 tests.
# Completed 3429/915 tests.
# Completed 3449/915 tests.
# Completed 3461/915 tests.
# Completed 3467/915 tests.
# Completed 3471/915 tests.
# Completed 3473/915 tests.
# Completed 3476/915 tests.
# Completed 3482/915 tests.
# Completed 3504/915 tests.
# Completed 3509/915 tests.
# Completed 3511/915 tests.
# Completed 3524/915 tests.
# Completed 3527/915 tests.
# Completed 3530/915 tests.
# Saved progress at 3530 tests.
# Completed 3531/915 tests.
# Completed 3534/915 tests.
# Completed 3540/915 tests.
# Saved progress at 3540 tests.
# Completed 3541/915 tests.
# Completed 3542/915 tests.
# Completed 3562/915 tests.
# Completed 3572/915 tests.
# Completed 3574/915 tests.
# Completed 3579/915 tests.
# Completed 3581/915 tests.
# Completed 3585/915 tests.
# Completed 3603/915 tests.
# Completed 3608/915 tests.
# Completed 3612/915 tests.
# Completed 3617/915 tests.
# Completed 3623/915 tests.
# Completed 3626/915 tests.
# Completed 3628/915 tests.
# Completed 3629/915 tests.
# Completed 3646/915 tests.
# Completed 3648/915 tests.
# Completed 3651/915 tests.
# Completed 3652/915 tests.
# Completed 3661/915 tests.
# Completed 3664/915 tests.
# Completed 3666/915 tests.
# Completed 3667/915 tests.
# Completed 3668/915 tests.
# Completed 3676/915 tests.
# Completed 3678/915 tests.
# Completed 3687/915 tests.
# Completed 3691/915 tests.
# Completed 3692/915 tests.
# Completed 3693/915 tests.
# Completed 3694/915 tests.
# Completed 3698/915 tests.
# Completed 3708/915 tests.
# Completed 3716/915 tests.
# Completed 3725/915 tests.
# Completed 3729/915 tests.
# Completed 3736/915 tests.
# Completed 3737/915 tests.
# Completed 3744/915 tests.
# Completed 3749/915 tests.
# Completed 3750/915 tests.
# Saved progress at 3750 tests.
# Completed 3751/915 tests.
# Completed 3753/915 tests.
# Completed 3755/915 tests.
# Completed 3756/915 tests.
# Completed 3757/915 tests.
# Completed 3758/915 tests.
# Completed 3760/915 tests.
# Saved progress at 3760 tests.
# Completed 3764/915 tests.
# Completed 3781/915 tests.
# Completed 3783/915 tests.
# Completed 3789/915 tests.
# Completed 3792/915 tests.
# Completed 3793/915 tests.
# Completed 3794/915 tests.
# Completed 3795/915 tests.
# Completed 3799/915 tests.
# Completed 3801/915 tests.
# Completed 3803/915 tests.
# Completed 3806/915 tests.
# Completed 3809/915 tests.
# Completed 3811/915 tests.
# Completed 3812/915 tests.
# Completed 3813/915 tests.
# Completed 3818/915 tests.
# Completed 3826/915 tests.
# Completed 3832/915 tests.
# Completed 3843/915 tests.
# Completed 3845/915 tests.
# Completed 3851/915 tests.
# Completed 3852/915 tests.
# Completed 3871/915 tests.
# Completed 3878/915 tests.
# Completed 3879/915 tests.
# Completed 3882/915 tests.
# Completed 3885/915 tests.
# Completed 3886/915 tests.
# Completed 3887/915 tests.
# Completed 3891/915 tests.
# Completed 3893/915 tests.
# Completed 3895/915 tests.
# Completed 3896/915 tests.
# Completed 3898/915 tests.
# Completed 3899/915 tests.
# Completed 3900/915 tests.
# Saved progress at 3900 tests.
# Completed 3908/915 tests.
# Completed 3916/915 tests.
# Completed 3918/915 tests.
# Completed 3919/915 tests.
# Completed 3932/915 tests.
# Completed 3934/915 tests.
# Completed 3935/915 tests.
# Completed 3936/915 tests.
# Completed 3940/915 tests.
# Saved progress at 3940 tests.
# Completed 3944/915 tests.
# Completed 3945/915 tests.
# Completed 3947/915 tests.
# Completed 3951/915 tests.
# Completed 3952/915 tests.
# Completed 3955/915 tests.
# Completed 3956/915 tests.
# Completed 3967/915 tests.
# Completed 3969/915 tests.
# Completed 3970/915 tests.
# Saved progress at 3970 tests.
# Completed 3976/915 tests.
# Completed 3984/915 tests.
# Completed 3986/915 tests.
# Completed 3987/915 tests.
# Completed 3998/915 tests.
# Completed 4006/915 tests.
# Completed 4022/915 tests.
# Completed 4028/915 tests.
# Completed 4031/915 tests.
# Completed 4037/915 tests.
# Completed 4042/915 tests.
# Completed 4056/915 tests.
# Completed 4057/915 tests.
# Completed 4061/915 tests.
# Completed 4064/915 tests.
# Completed 4070/915 tests.
# Saved progress at 4070 tests.
# Completed 4078/915 tests.
# Completed 4079/915 tests.
# Completed 4096/915 tests.
# Completed 4097/915 tests.
# Completed 4102/915 tests.
# Completed 4108/915 tests.
# Completed 4110/915 tests.
# Saved progress at 4110 tests.
# Completed 4111/915 tests.
# Completed 4116/915 tests.
# Completed 4118/915 tests.
# Completed 4133/915 tests.
# Completed 4148/915 tests.
# Completed 4155/915 tests.
# Completed 4156/915 tests.
# Completed 4160/915 tests.
# Saved progress at 4160 tests.
# Completed 4196/915 tests.
# Completed 4199/915 tests.
# Completed 4208/915 tests.
# Completed 4223/915 tests.
# Completed 4232/915 tests.
# Completed 4233/915 tests.
# Completed 4235/915 tests.
# Completed 4236/915 tests.
# Completed 4237/915 tests.
# Completed 4238/915 tests.
# Completed 4239/915 tests.
# Completed 4244/915 tests.
# Completed 4245/915 tests.
# Completed 4249/915 tests.
# Completed 4251/915 tests.
# Completed 4268/915 tests.
# Completed 4279/915 tests.
# Completed 4280/915 tests.
# Saved progress at 4280 tests.
# Completed 4281/915 tests.
# Completed 4284/915 tests.
# Completed 4296/915 tests.
# Completed 4298/915 tests.
# Completed 4304/915 tests.
# Completed 4321/915 tests.
# Completed 4327/915 tests.
# Completed 4336/915 tests.
# Completed 4341/915 tests.
# Completed 4367/915 tests.
# Completed 4372/915 tests.
# Completed 4373/915 tests.
# Completed 4380/915 tests.
# Saved progress at 4380 tests.
# Completed 4388/915 tests.
# Completed 4393/915 tests.
# Completed 4405/915 tests.
# Completed 4411/915 tests.
# Completed 4418/915 tests.
# Completed 4419/915 tests.
# Completed 4421/915 tests.
# Completed 4428/915 tests.
# Completed 4436/915 tests.
# Completed 4446/915 tests.
# Completed 4456/915 tests.
# Completed 4462/915 tests.
# Completed 4466/915 tests.
# Completed 4469/915 tests.
# Completed 4473/915 tests.
# Completed 4475/915 tests.
# Completed 4476/915 tests.
# Completed 4477/915 tests.
# Completed 4478/915 tests.
# Completed 4485/915 tests.
# Completed 4486/915 tests.
# Completed 4495/915 tests.
# Completed 4501/915 tests.
# Completed 4505/915 tests.
# Completed 4507/915 tests.
# Completed 4509/915 tests.
# Completed 4511/915 tests.
# Completed 4513/915 tests.
# Completed 4514/915 tests.
# Completed 4518/915 tests.
# Completed 4523/915 tests.
# Completed 4529/915 tests.
# Completed 4537/915 tests.
# Completed 4546/915 tests.
# Completed 4549/915 tests.
# Completed 4551/915 tests.
# Completed 4552/915 tests.
# Completed 4555/915 tests.
# Completed 4561/915 tests.
# Completed 4565/915 tests.
# Completed 4566/915 tests.
# Completed 4570/915 tests.
# Saved progress at 4570 tests.
# Completed 4592/915 tests.
# Completed 4596/915 tests.
# Completed 4597/915 tests.
# Completed 4599/915 tests.
# Completed 4601/915 tests.
# Completed 4606/915 tests.
# Completed 4610/915 tests.
# Saved progress at 4610 tests.
# Completed 4611/915 tests.
# Completed 4616/915 tests.
# Completed 4621/915 tests.
# Completed 4643/915 tests.
# Completed 4644/915 tests.
# Completed 4647/915 tests.
# Completed 4649/915 tests.
# Completed 4652/915 tests.
# Completed 4660/915 tests.
# Saved progress at 4660 tests.
# Completed 4677/915 tests.
# Completed 4682/915 tests.
# Completed 4687/915 tests.
# Completed 4692/915 tests.
# Completed 4701/915 tests.
# Completed 4702/915 tests.
# Completed 4703/915 tests.
# Completed 4709/915 tests.
# Completed 4710/915 tests.
# Saved progress at 4710 tests.
# Completed 4715/915 tests.
# Completed 4717/915 tests.
# Completed 4719/915 tests.
# Completed 4724/915 tests.
# Completed 4726/915 tests.
# Completed 4732/915 tests.
# Completed 4733/915 tests.
# Completed 4734/915 tests.
# Completed 4744/915 tests.
# Completed 4745/915 tests.
# Completed 4746/915 tests.
# Completed 4750/915 tests.
# Saved progress at 4750 tests.
# Completed 4754/915 tests.
# Completed 4762/915 tests.
# Completed 4763/915 tests.
# Completed 4771/915 tests.
# Completed 4773/915 tests.
# Completed 4776/915 tests.
# Completed 4777/915 tests.
# Completed 4778/915 tests.
# Completed 4794/915 tests.
# Completed 4796/915 tests.
# Completed 4799/915 tests.
# Completed 4800/915 tests.
# Saved progress at 4800 tests.
# Completed 4812/915 tests.
# Completed 4818/915 tests.
# Completed 4829/915 tests.
# Completed 4830/915 tests.
# Saved progress at 4830 tests.
# Completed 4835/915 tests.
# Completed 4837/915 tests.
# Completed 4838/915 tests.
# Completed 4840/915 tests.
# Saved progress at 4840 tests.
# Completed 4841/915 tests.
# Completed 4843/915 tests.
# Completed 4845/915 tests.
# Completed 4846/915 tests.
# Completed 4859/915 tests.
# Final results have been saved to 'feature_combination_results.csv'
